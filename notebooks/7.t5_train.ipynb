# %%
import os
import sys
import random
import itertools
import pickle
import json

import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from tqdm import tqdm
from pandarallel import pandarallel

import pymorphy2
import nltk
from nltk.tokenize import word_tokenize, wordpunct_tokenize, sent_tokenize

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, f1_score

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import TensorDataset, DataLoader

from keras.preprocessing.sequence import pad_sequences

from transformers import T5Model, T5Tokenizer, T5ForConditionalGeneration

from tqdm.auto import trange
import gc

sys.path.append("..")
from src import *

def init_random_seed(value=0):
    random.seed(value)
    np.random.seed(value)
    torch.manual_seed(value)
    torch.cuda.manual_seed(value)
    torch.backends.cudnn.deterministic = True
init_random_seed()
    
pd.set_option('display.max_colwidth', 255)
tqdm.pandas()
pandarallel.initialize(progress_bar=True, nb_workers=8, use_memory_fs=False)

# %load_ext autoreload
# %autoreload 2
# Out:
# INFO: Pandarallel will run on 8 workers.
# INFO: Pandarallel will use standard multiprocessing data transfer (pipe) to transfer data between the main process and workers.

# %%
with open("../data/fill_tasks_t5.pickle", "rb") as f:
    fill_tasks = pickle.load(f)
new_tasks = [] 
for task in fill_tasks:
    if len(task[0]) < 350:
        new_tasks.append(task)
print(len(new_tasks) / len(fill_tasks))
fill_tasks = new_tasks

MODEL_NAME = "sberbank-ai/ruT5-base"

tokenizer = T5Tokenizer.from_pretrained(MODEL_NAME)
model = T5ForConditionalGeneration.from_pretrained(MODEL_NAME)
model.cuda()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)

batch_size = 16  # сколько примеров показываем модели за один шаг
report_steps = 200  # раз в сколько шагов печатаем результат
epochs = 1  # сколько раз мы покажем данные модели

model.train()
losses = []
try:
    for epoch in range(epochs):
        print('EPOCH', epoch)
        random.shuffle(fill_tasks)
        for i in trange(0, int(len(fill_tasks) / batch_size)):
            batch = fill_tasks[i * batch_size: (i + 1) * batch_size]
            # кодируем вопрос и ответ 
            x = tokenizer([p[0] for p in batch], return_tensors='pt', padding=True).to(model.device)
            y = tokenizer([p[1] for p in batch], return_tensors='pt', padding=True).to(model.device)
            # -100 - специальное значение, позволяющее не учитывать токены
            y.input_ids[y.input_ids == 0] = -100
            # вычисляем функцию потерь
            loss = model(
                input_ids=x.input_ids,
                attention_mask=x.attention_mask,
                labels=y.input_ids,
                decoder_attention_mask=y.attention_mask,
                return_dict=True
            ).loss
            # делаем шаг градиентного спуска
            loss.backward()
            optimizer.step()
            optimizer.zero_grad()
            # печатаем скользящее среднее значение функции потерь
            losses.append(loss.item())
            if i % report_steps == 0:
                print('step', i, 'loss', np.mean(losses[-report_steps:]))

            del x, y
            gc.collect()
            torch.cuda.empty_cache()
except Exception as ex: 
    print("ERROR")
    model.save_pretrained(f"../models/t5/t5_trained_{i}.model")
    raise
    
model.save_pretrained(f"../models/t5/t5_trained_full.model")
# Out:
# 0.9776699305845254
# EPOCH 0
#   0%|          | 0/23582 [00:00<?, ?it/s]
# step 0 loss 14.187641143798828
# step 200 loss 3.074126591384411
# step 400 loss 1.2904317392408848
# step 600 loss 0.9118332402408122
# step 800 loss 0.7503897586092353
# step 1000 loss 0.644437567256391
# step 1200 loss 0.6028430039249361
# step 1400 loss 0.5449692789837718
# step 1600 loss 0.46744242902845146
# step 1800 loss 0.45731070790439843
# step 2000 loss 0.41072798665612936
# step 2200 loss 0.38936339505016804
# step 2400 loss 0.3815291952341795
# step 2600 loss 0.35272137619554994
# step 2800 loss 0.36231855985708533
# step 3000 loss 0.33569877207279203
# step 3200 loss 0.33495756428223106
# step 3400 loss 0.335749902902171
# step 3600 loss 0.3357129411958158
# step 3800 loss 0.3064714600984007
# step 4000 loss 0.28765694751404225
# step 4200 loss 0.2958027189038694
# step 4400 loss 0.2664230223465711
# step 4600 loss 0.26277364682406185
# step 4800 loss 0.26945081979036334
# step 5000 loss 0.2512307298090309
# step 5200 loss 0.2564898593723774
# step 5400 loss 0.23393741123378275
# step 5600 loss 0.24112421906553208
# step 5800 loss 0.21724024978931994
# step 6000 loss 0.23116891333367676
# step 6200 loss 0.2440936197619885
# step 6400 loss 0.22875073981005697
# step 6600 loss 0.21873906070366503
# step 6800 loss 0.21570706334896386
# step 7000 loss 0.20626402182970197
# step 7200 loss 0.21259292574599387
# step 7400 loss 0.2081540726311505
# step 7600 loss 0.2034857481624931
# step 7800 loss 0.20196441071107984
# step 8000 loss 0.19308864057064057
# step 8200 loss 0.2038456326816231
# step 8400 loss 0.18883200508076697
# step 8600 loss 0.1888392684236169
# step 8800 loss 0.18676925530657174
# step 9000 loss 0.18309743996243924
# step 9200 loss 0.19188907522242515
# step 9400 loss 0.19125337444245816
# step 9600 loss 0.18900868742726742
# step 9800 loss 0.19277560549788178
# step 10000 loss 0.17843075188342483
# step 10200 loss 0.1760100289201364
# step 10400 loss 0.18101333393715321
# step 10600 loss 0.17899366441182793
# step 10800 loss 0.16451378094032407
# step 11000 loss 0.1633346061920747
# step 11200 loss 0.15860968080349266
# step 11400 loss 0.16569492174312472
# step 11600 loss 0.17280686968937517
# step 11800 loss 0.1561754606058821
# step 12000 loss 0.15692569439066573
# step 12200 loss 0.1762411404028535
# step 12400 loss 0.1751616378314793
# step 12600 loss 0.166508482566569
# step 12800 loss 0.17694183106534184
# step 13000 loss 0.1682813860429451
# step 13200 loss 0.16346616312395781
# step 13400 loss 0.14651306688319893
# step 13600 loss 0.15839198025641962
# step 13800 loss 0.15421350144781173
# step 14000 loss 0.1510521806264296
# step 14200 loss 0.16309916614089162
# step 14400 loss 0.15402570475824176
# step 14600 loss 0.1417348486057017
# step 14800 loss 0.14660011644009502
# step 15000 loss 0.14821790602523832
# step 15200 loss 0.15121599191334098
# step 15400 loss 0.14837352872360499
# step 15600 loss 0.14251734289340676
# step 15800 loss 0.1426421171007678
# step 16000 loss 0.14428415392991156
# step 16200 loss 0.135686710330192
# step 16400 loss 0.14912739923922344
# step 16600 loss 0.16313610238023102
# step 16800 loss 0.13571691065328195
# step 17000 loss 0.14525367733091116
# step 17200 loss 0.13940848814789206
# step 17400 loss 0.143583458699286
# step 17600 loss 0.1409260221477598
# step 17800 loss 0.14077652262989432
# step 18000 loss 0.12184969544643537
# step 18200 loss 0.1345820421294775
# step 18400 loss 0.13186683696927504
# step 18600 loss 0.1298060148744844
# step 18800 loss 0.13853574089240284
# step 19000 loss 0.12960872519761324
# step 19200 loss 0.1368609612574801
# step 19400 loss 0.14054153172764927
# step 19600 loss 0.13138078830204905
# step 19800 loss 0.1429886926431209
# step 20000 loss 0.1274802841572091
# step 20200 loss 0.1366011017328128
# step 20400 loss 0.13005416432395578
# step 20600 loss 0.1310098535940051
# step 20800 loss 0.13530988614540548
# step 21000 loss 0.1239703196939081
# step 21200 loss 0.12103267051978037
# step 21400 loss 0.12700590695021674
# step 21600 loss 0.12944835209287703
# step 21800 loss 0.12759852945804595
# step 22000 loss 0.13479205208830536
# step 22200 loss 0.1253160633193329
# step 22400 loss 0.12023485178127885
# step 22600 loss 0.11897708924720064
# step 22800 loss 0.1274544763751328
# step 23000 loss 0.11732032063999213
# step 23200 loss 0.13185822502709926
# step 23400 loss 0.13337107959203423

# %% [markdown]
# ## Scoring

# %%
lenta_test = pd.read_csv("../data/lenta_test_t5.csv")

test_texts = list(map(lambda x: x.split(" "), lenta_test["text_upd"].to_list()))
test_labels = list(map(lambda x: x.split(" "), lenta_test["labels_upd"].to_list()))

def get_sentences(text, labels):
    sentences = sent_tokenize(" ".join(text), language="russian")
    sent_labels = []
    
    i = 0
    for sent in sentences:
        sent = sent.split(" ")
        sent_labels.append(" ".join(labels[i:i+len(sent)]))
        i += len(sent)
    return sentences, sent_labels

sentences = []
sentences_labels = []
for text, labels in tqdm(zip(test_texts, test_labels)):
    sent, sent_labels = get_sentences(text, labels)
    sentences.extend(sent)
    sentences_labels.extend(sent_labels)
# Out:
# 100853it [00:10, 9360.47it/s]

# %%
new_sentences = []
new_sentences_labels = []
for i, sent in enumerate(sentences):
    if len(sent.split(" ")) <= 10: # 50
        new_sentences.append(sent)
        new_sentences_labels.append(sentences_labels[i])
        

print(len(new_sentences) / len(sentences))        
sentences = new_sentences
sentences_labels = new_sentences_labels
# Out:
# 0.16689332146699995

# %%
abbr_detection = AbbrDetection()

morph = pymorphy2.MorphAnalyzer(lang="ru", 
                                units=[pymorphy2.units.DictionaryAnalyzer()])
def normalize(word):
    parse_list = morph.parse(str(word))
    if parse_list != []:
        return parse_list[0].normal_form
    else:
        return word.lower()
    
def create_fill_task(sent, i):
    new_sent = sent.copy()
    new_sent[i] = "<extra_id_1>"
    return f"fill {sent[i]} | {' '.join(new_sent)}"

tasks = []
preds = []

for sent_i in tqdm(range(len(sentences))):
    sent = sentences[sent_i].split(" ")
    sent_labels = sentences_labels[sent_i].split(" ")
    
    for word_i in range(len(sent)):
        word = sent[word_i]
        label = sent_labels[word_i]
        
        norm_word = normalize(word)
        if abbr_detection.word_is_abbr(norm_word):
            task = create_fill_task(sent, word_i)
            tasks.append((sent_i, word_i, task))
        
    preds.append(["_"] * len(sent))
# Out:
# 100%|██████████| 170461/170461 [02:04<00:00, 1368.82it/s]

# %%
# with open("../data/preds_test_t5.pickle", "wb") as f:
#     pickle.dump(preds, f)
    
# with open("../data/tasks_test_t5.pickle", "wb") as f:
#     pickle.dump(tasks, f)  

with open("../data/preds_test_t5.pickle", "rb") as f:
    preds = pickle.load(f)
    
with open("../data/tasks_test_t5.pickle", "rb") as f:
    tasks = pickle.load(f)  

MODEL_NAME = "sberbank-ai/ruT5-base"
tokenizer = T5Tokenizer.from_pretrained(MODEL_NAME)
model = T5ForConditionalGeneration.from_pretrained(f"../models/t5/t5_trained_full.model")
model.cuda()
get_model_params_num(model)
# Out:
# 222903552

# %%
batch_size = 64 # 32

for i in trange(0, int(len(tasks) / batch_size)):
    batch = tasks[i * batch_size: (i + 1) * batch_size]
    
    batch_sent_i = [p[0] for p in batch]
    batch_word_i = [p[1] for p in batch]
    inputs = tokenizer([p[2] for p in batch], return_tensors='pt', padding=True).to(model.device)
    
    with torch.no_grad():
        hypotheses = model.generate(**inputs, num_beams=5)
    
    for j in range(len(batch)):
        sent_i = batch_sent_i[j]
        word_i = batch_word_i[j]
        preds[sent_i][word_i] = tokenizer.decode(hypotheses[j], skip_special_tokens=True).replace(" ", "=")
        
    del batch
    gc.collect()
    torch.cuda.empty_cache()
# Out:
#   0%|          | 0/580 [00:00<?, ?it/s]

# %%
preds = [" ".join(pred) for pred in preds]

# %%
# with open("../data/preds_t5.pickle", "wb") as f:
#     pickle.dump(preds, f) 

with open("../data/preds_t5.pickle", "rb") as f:
    preds = pickle.load(f)

# %%
full_preds = []
full_labels = []
for i in range(len(preds)):
    pred = preds[i]
    true = sentences_labels[i]
    if len(pred.split(" ")) == len(true.split(" ")):
        full_preds.extend([preds[i]])
        full_labels.extend([sentences_labels[i]])
full_preds = " ".join(full_preds).split(" ")
full_labels = " ".join(full_labels).split(" ")

# %%
len(full_preds) == len(full_labels)
# Out:
# True

# %%
morph = pymorphy2.MorphAnalyzer(lang="ru", 
                                units=[pymorphy2.units.DictionaryAnalyzer()])

def norm_tokenize(line):
    tokenized_norm = []
    for word in word_tokenize(line):
        parse_list = morph.parse(str(word))
        if parse_list != []:
            norm_form = parse_list[0].normal_form
        else:
            norm_form = word
        tokenized_norm.append(norm_form)
    return tokenized_norm

# %%
full_preds_norm = []
for label in tqdm(full_preds):
    if label != "_":
        label = label.replace("=", " ").lower()
        label_norm = norm_tokenize(label)
        full_preds_norm.append(" ".join(label_norm))
    else:
        full_preds_norm.append("_")
# Out:
# 100%|██████████| 1360937/1360937 [00:06<00:00, 205580.27it/s]

# %%
full_labels_norm = []
for label in tqdm(full_labels):
    if label != "_":
        label = label.replace("=", " ").lower()
        label_norm = norm_tokenize(label)
        full_labels_norm.append(" ".join(label_norm))
    else:
        full_labels_norm.append("_")
# Out:
# 100%|██████████| 1360937/1360937 [00:00<00:00, 1547142.42it/s]

# %%
f1_score(full_labels_norm, full_preds_norm, average="macro")
# Out:
# 0.034699985738502095

# %%
def get_filtred_accuracy_score(true, pred):
    stacked = zip(true, pred)
    filt_stacked = list(filter(lambda x: x != ("_", "_"), stacked))
    true, pred = zip(*filt_stacked)
    return accuracy_score(true, pred)

# %%
get_filtred_accuracy_score(full_labels_norm, full_preds_norm)
# Out:
# 0.1711422953645595

# %%
stacked = zip(full_labels_norm, full_preds_norm)
filt_stacked = list(filter(lambda x: x != ("_", "_"), stacked))
true, pred = zip(*filt_stacked)

# %%
filt_stacked
# Out:
# [('_', 'международный паралимпийский суд'),
#  ('_', 'российский федерация'),
#  ('_', 'рига чемпион'),
#  ('передача данные', 'передача данные'),
#  ('_', 'двухпортовой'),
#  ('_', 'геймальному падение'),
#  ('_', 'феерация лига чемпион'),
#  ('_', 'бережно-космической станция'),
#  ('_', 'управление по борьба с экономический преступление'),
#  ('_', 'наса'),
#  ('информация', 'информация'),
#  ('_', 'республика штат право дума'),
#  ('_', 'всероссийский автономный комиссия'),
#  ('_', 'информационный агентство'),
#  ('_', 'федеральный агентство'),
#  ('_', 'голодный дума'),
#  ('северный корея', 'следственный комитет'),
#  ('международный', 'международный'),
#  ('_', 'международный антидопинговый агентство'),
#  ('_', 'марецкий уголовный розыск'),
#  ('_', 'мейсон'),
#  ('информация', 'информация'),
#  ('_', 'инвестиционный фонд'),
#  ('_', 'миллион'),
#  ('_', 'оперативный'),
#  ('_', 'законодательный собрание'),
#  ('_', 'манерский автономный округ'),
#  ('_', 'тунецкий автономный округ'),
#  ('_', 'тимарский автономный округ'),
#  ('финансовый результат', 'фондовый рынок'),
#  ('миллиард', 'миллиард'),
#  ('_', 'бюро управление полёт'),
#  ('кабинет министр', 'кабинет министр'),
#  ('_', 'северный корея'),
#  ('сентябрь', 'сентябрь'),
#  ('_', 'урган'),
#  ('_', 'организация освобождение палестина'),
#  ('_', 'соединить штат америка'),
#  ('_', 'государственный назначение'),
#  ('_', 'библиотека библиотектура'),
#  ('_', 'греческий металлургический комбинат'),
#  ('_', 'государственный телевидение'),
#  ('_', 'информационный телевидение'),
#  ('_', 'европейский телевидение'),
#  ('_', 'телевидение'),
#  ('вертолёт', 'вертолёт'),
#  ('_', 'южный федеральный округ'),
#  ('_', 'компьютерный система'),
#  ('_', 'пол'),
#  ('_', 'соединить штат америка'),
#  ('_', 'движение против нелегальный иммиграция'),
#  ('_', 'несчастный случай'),
#  ('верховный рада', 'верховный рада'),
#  ('_', 'цифровой телефон'),
#  ('_', 'фригата'),
#  ('_', 'эра уголовный криз'),
#  ('_', 'биография'),
#  ('_', 'предупреждение о ракетный заказ'),
#  ('международный космический станция', 'международный космический станция'),
#  ('_', 'халянов'),
#  ('_', 'соединить штат америка'),
#  ('страница', 'страница'),
#  ('_', 'херцефальном автономный округ'),
#  ('_', 'следственный комитет'),
#  ('километр', 'километр'),
#  ('_', 'буркина-поттера'),
#  ('_', 'бумаговый телескоп'),
#  ('_', 'мерополитен'),
#  ('миллион', 'миллион'),
#  ('_', 'паннерский автономный округ'),
#  ('_', 'платформер'),
#  ('_', 'платёжный система'),
#  ('сентябрь', 'сентябрь'),
#  ('_', 'телевидение'),
#  ('сентябрь', 'сентябрь'),
#  ('_', 'фбр'),
#  ('командный пункт', 'командный пункт'),
#  ('_', 'учебный залповый ракета'),
#  ('_', 'экономический арабский союз'),
#  ('_', 'забайкальский автономный округ'),
#  ('_', 'аэрологический агентство'),
#  ('_', 'видеочат'),
#  ('_', 'видеозвонок'),
#  ('_', 'гаспиталь'),
#  ('_', 'малый и дальность'),
#  ('федеральный бюджет', 'федеральный бюджет'),
#  ('_', 'взвоенный суд'),
#  ('_', 'капитан'),
#  ('_', 'международный валютный фонд'),
#  ('_', 'лига арабский государство'),
#  ('_', 'любымым арбитражный суд'),
#  ('миллиард', 'миллиард'),
#  ('_', 'берекер'),
#  ('_', 'компьютерный компьютерный система'),
#  ('_', 'ракетный комплекс'),
#  ('_', 'ганнецкий автономный округ'),
#  ('_', 'бреным виком'),
#  ('_', 'сенсионному телефон'),
#  ('_', 'рональд новгород'),
#  ('_', 'хоккейный клуб'),
#  ('_', 'национальный банк украина'),
#  ('_', '« комсомольский правда »'),
#  ('_', 'марийский автономный служба'),
#  ('_', 'садовый телефон'),
#  ('_', 'главное следственный управление'),
#  ('_', 'гаджи-мансийского автономный округ'),
#  ('_', 'родильный дом'),
#  ('_', 'рама'),
#  ('_', 'ракета-носитель'),
#  ('_', 'приветствовать'),
#  ('_', 'канентального антидопинговый агентство'),
#  ('_', 'канерского автономный округ'),
#  ('_', 'оперативный система'),
#  ('_', 'международный культура и кинематографист'),
#  ('международный комитет', '« московский комсомолец »'),
#  ('_', 'источник питание'),
#  ('_', 'московский авиационный комитет'),
#  ('_', 'тихоокеанский союз'),
#  ('« интерфакс »', '« интерфакс »'),
#  ('система страхование вклад', 'система страхование вклад'),
#  ('_', 'норецкого металлургический комбинат'),
#  ('вертолёт', 'вертолёт'),
#  ('_', 'альфа-банк'),
#  ('_', 'информационный агентство'),
#  ('_', 'российский федерация'),
#  ('управление федеральный антимонопольный служба',
#   'управление федеральный антимонопольный служба'),
#  ('_', 'агентство по страхование вклад'),
#  ('_', 'промышленный комплекс'),
#  ('_', 'рынок ценный бумага'),
#  ('_', 'агабаев'),
#  ('_', 'нано-нитарные завод'),
#  ('_', 'шуточный телефон'),
#  ('_', 'блэк'),
#  ('_', 'макаров'),
#  ('_', 'король россия'),
#  ('_', 'государственный аккуму'),
#  ('_', 'болотный'),
#  ('_', 'комсомольский правда'),
#  ('_', 'комсомольская-на-амуре'),
#  ('_', 'харабет'),
#  ('_', 'воронов'),
#  ('_', 'информационный агентство'),
#  ('_', 'виза'),
#  ('_', 'булановский'),
#  ('_', 'булановский'),
#  ('_', 'старый школа'),
#  ('_', 'андрей'),
#  ('вертолёт', 'вертолёт'),
#  ('_', 'государственный средство'),
#  ('миллион', 'миллион'),
#  ('_', 'центральный банк'),
#  ('_', 'сми'),
#  ('_', 'военно-академия наука'),
#  ('_', 'центральный командование по военно-технический сотрудничество'),
#  ('_', 'еврейский автономный колония'),
#  ('_', 'гол'),
#  ('_', 'квинтол'),
#  ('_', '« российский железный дорога »'),
#  ('_', 'почётный телефон'),
#  ('нокаут', 'нокаут'),
#  ('_', 'украинский автономный банк'),
#  ('февраль', 'февраль'),
#  ('_', 'российский автономный округ'),
#  ('_', 'единый россия'),
#  ('_', 'мегаватт'),
#  ('_', 'азиатско-тихоокеанский регион'),
#  ('_', 'тяжкий телесный повреждение'),
#  ('миллион', 'миллион'),
#  ('_', 'луганский информационный центр'),
#  ('_', 'европейский союз промышленник и предприниматель'),
#  ('информация', 'информация'),
#  ('_', 'государственный тайна'),
#  ('_', 'федерация теннисистов-профессионалов'),
#  ('_', 'азиатско-тихоокеанский региональный центр'),
#  ('_', 'фара ледовитый арабский союз'),
#  ('международный', 'международный'),
#  ('_', 'приморский край'),
#  ('миллиард', 'миллиард'),
#  ('_', 'сквояновский'),
#  ('_', 'соединить штат америка'),
#  ('_', 'соединить штат америка'),
#  ('_', 'украинский православный церковь'),
#  ('_', 'российский федерация'),
#  ('_', 'таргызстан'),
#  ('_', 'управление федеральный служба новость'),
#  ('_', 'имиджевый борьба'),
#  ('_', 'информационный агентство'),
#  ('_', 'хабирская автономный дума'),
#  ('_', 'ханты-мансийский автономный дом'),
#  ('_', 'телевидение'),
#  ('совет директор', 'совет директор'),
#  ('_', 'информационный агентство'),
#  ('_', 'информационный агентство'),
#  ('_', 'ходачева'),
#  ('_', 'ходарский автономный округ'),
#  ('_', 'управление по борьба с организовать преступность'),
#  ('_', 'андрей'),
#  ('_', 'региональный оперативный штаб'),
#  ('миллион', 'миллион'),
#  ('московский область', 'московский область'),
#  ('_', 'антимонопольный комитет'),
#  ('_', 'зелёный крест'),
#  ('_', 'тур'),
#  ('_', 'уиллом поттер'),
#  ('_', 'блок юлия тимошенко'),
#  ('петербург', 'петербург'),
#  ('_', 'сибирский автономный округ'),
#  ('_', 'постаповале'),
#  ('_', 'информационный агентство'),
#  ('_', 'пассажирский телевидение'),
#  ('_', 'белый крест'),
#  ('_', 'госпиталь'),
#  ('_', 'полиграфический компания'),
#  ('_', 'центральный банк'),
#  ('_', 'макаров'),
#  ('страница', 'страница'),
#  ('_', 'киевский городской округ'),
#  ('_', '« московский железный »'),
#  ('пресс-конференция', 'пресс-конференция'),
#  ('килограмм', 'килограмм'),
#  ('_', 'ливонский автономный суд'),
#  ('_', 'генеральный директор'),
#  ('_', 'чемпионат мир'),
#  ('информация', 'информация'),
#  ('_', 'орган внутренний дело'),
#  ('_', 'украинский автономный округ'),
#  ('_', 'чже-ненецком автономный округ'),
#  ('_', 'ханты-мансийский автономный округ'),
#  ('_', 'организация объединить нация'),
#  ('_', 'информационный агентство'),
#  ('не быть', 'не быть'),
#  ('российский федерация', 'российский федерация'),
#  ('_', 'лопановского автономный госпиталь'),
#  ('_', 'информационный агентство'),
#  ('_', 'управление по безопасность'),
#  ('_', 'федеральный агентство'),
#  ('_', 'чрезвычайный происшествие'),
#  ('_', 'антитеррористический агентство'),
#  ('_', 'северный корея'),
#  ('_', 'капитан'),
#  ('_', 'командир рота'),
#  ('_', 'компьютерный система'),
#  ('_', 'главное следственный управление'),
#  ('_', 'пожизненный лишение свобода'),
#  ('сентябрь', 'сентябрь'),
#  ('_', 'соединить штат америка'),
#  ('_', 'вооружённый сила'),
#  ('_', 'соединить штат америка'),
#  ('_', 'сибирский государственный управление'),
#  ('миллион', 'миллион'),
#  ('_', 'авиационный комплекс'),
#  ('_', 'разведывательный взвод'),
#  ('_', 'государственный охрана'),
#  ('_', 'массовый адронный коллайдер'),
#  ('_', 'система страхование вклад'),
#  ('_', 'коммерческий арбитражный суд'),
#  ('генеральный прокуратура', 'генеральный прокуратура'),
#  ('_', 'информационный агентство'),
#  ('_', 'чрезвычайный ситуация'),
#  ('_', 'российский федерация'),
#  ('не быть', 'не быть'),
#  ('_', 'организация объединить нация'),
#  ('_', 'европейский союз конькобежец'),
#  ('_', 'российский футбольный премьер-лига'),
#  ('_', 'антимонопольный комитет'),
#  ('нокаут', 'нокаут'),
#  ('_', 'чрезвычайный происшествие'),
#  ('_', 'антитеррористический округ'),
#  ('_', 'соединить штат америка'),
#  ('_', 'федеральный служба по финансовый рынок'),
#  ('_', 'академия наука'),
#  ('_', 'европейский союз футбольный теннисистов-профессионалов'),
#  ('_', 'близецкий новгород'),
#  ('_', 'пригод'),
#  ('_', 'организация освобождение палестина'),
#  ('не быть', 'не быть'),
#  ('миллион', 'миллион'),
#  ('_', 'гипертонический криз'),
#  ('_', 'соединить штат америка'),
#  ('_', 'соединить штат америка'),
#  ('_', 'нефтетехнический институт'),
#  ('_', 'избирательный комиссия'),
#  ('_', 'муниципальный округ'),
#  ('_', 'портовый университет'),
#  ('_', 'десятый алюминий'),
#  ('_', 'семидюймовых'),
#  ('_', 'восьмой ядерный баллистический ракета'),
#  ('_', 'дюйм'),
#  ('_', 'конституционный суд'),
#  ('_', 'европейский союз'),
#  ('_', 'фсб по безопасность'),
#  ('_', 'специальный служба'),
#  ('_', 'ганерский автономный округ'),
#  ('_', 'предприятие'),
#  ('_', 'чп'),
#  ('_', 'главное следственный управление'),
#  ('_', 'соединить штат америка'),
#  ('_', 'заместитель начальник'),
#  ('_', 'блокировка чейн'),
#  ('_', 'информация'),
#  ('национальный хоккейный лига', 'национальный хоккейный лига'),
#  ('_', 'национальный баскетбольный ассоциация'),
#  ('_', '« крыло совет »'),
#  ('_', 'кодекс о административный правонарушение'),
#  ('_', 'следственный комитет'),
#  ('_', 'чеченский республика'),
#  ('_', 'федеральный агентство по безопасность'),
#  ('_', 'организация объединить нация'),
#  ('_', 'лагер чемпион'),
#  ('_', 'информационный агентство'),
#  ('_', 'сторожевой военный суд'),
#  ('_', 'гундер-карабахская республика'),
#  ('километр', 'километр'),
#  ('_', 'соединить штат америка'),
#  ('мочь быть', 'мочь быть'),
#  ('_', 'военно-морской сила'),
#  ('_', 'медиакомпания'),
#  ('_', 'нефтепровод'),
#  ('_', 'рио-тихоокеанский региональный округ'),
#  ('_', 'кера'),
#  ('_', 'тала-лейтс'),
#  ('_', 'пивоваренный газа'),
#  ('_', 'сербия чемпион'),
#  ('_', 'ланецкого новгородский союз'),
#  ('нефтеперерабатывающий завод', 'нефтеперерабатывающий завод'),
#  ('_', 'европейский партия'),
#  ('_', 'оперативный бюро'),
#  ('_', 'гигаватт'),
#  ('_', 'единый россия'),
#  ('_', 'сельский автономный округ'),
#  ('_', 'кинологический служба'),
#  ('_', 'хоккейный клуб'),
#  ('_', 'матвей касьянов'),
#  ('_', 'космический отряд'),
#  ('_', 'информационный агентство'),
#  ('_', 'законодательный собрание украина'),
#  ('_', 'вооружённый сила'),
#  ('_', 'агентство по борьба с экономический преступление'),
#  ('_', 'ваня занецкий автономный округ'),
#  ('_', 'пожизненный лишение свобода'),
#  ('_', 'пол'),
#  ('_', 'приволжский федеральный округ'),
#  ('_', 'санкционный комитет'),
#  ('_', 'соединить штат америка'),
#  ('_', 'средство массовый информация'),
#  ('_', 'приволжский федеральный управление'),
#  ('_', 'камецкий автономный округ'),
#  ('_', 'союз биатлонист россия'),
#  ('_', 'служба безопасность украина'),
#  ('_', 'травмном пункт'),
#  ('« интерфакс »', '« интерфакс »'),
#  ('_', '« новый российский газета »'),
#  ('_', 'порнецкого автономный округ'),
#  ('_', 'московский область'),
#  ('_', 'дальний восток'),
#  ('_', 'фотостанцию'),
#  ('_', 'дальний восток'),
#  ('информация', 'информация'),
#  ('_', 'курдский автономный округ'),
#  ('_', 'атомный подводный лодка'),
#  ('информация', 'информация'),
#  ('_', 'национальный банк'),
#  ('_', 'российский футбольный союз'),
#  ('потребительский кредит', 'пресс-конференция'),
#  ('_', 'мейтс'),
#  ('_', 'матерский автономный округ'),
#  ('не быть', 'не быть'),
#  ('_', 'чп'),
#  ('миллион', 'миллион'),
#  ('_', 'стена'),
#  ('_', 'дочерний компания'),
#  ('_', 'вольный союз футбольный ассоциация'),
#  ('_', 'информационный агентство'),
#  ('_', 'федеральный налоговый служба'),
#  ('_', 'жж'),
#  ('_', 'информационный агентство'),
#  ('_', 'видеонаблюдение'),
#  ('_', 'аудиоэлектронные возможность'),
#  ('_', 'летоновский военный суд'),
#  ('московский', 'московский'),
#  ('_', 'гринерую служба судебный пристав'),
#  ('_', 'соединить штат америка'),
#  ('_', 'информационный агентство'),
#  ('_', 'фотосессия'),
#  ('_', 'соединить штат америка'),
#  ('_', 'руничный военный институт'),
#  ('_', 'кусьянов'),
#  ('миллион', 'миллион'),
#  ('_', 'бакарский автономный округ'),
#  ('_', 'многонаселённый'),
#  ('_', 'эйтс'),
#  ('_', 'ханты-мансийский автономный округ'),
#  ('_', 'орбитальный антимонопольный служба'),
#  ('_', 'ливановым'),
#  ('_', 'ганнецкого автономный округ'),
#  ('_', 'кпрф'),
#  ('_', 'рикпондента'),
#  ('_', 'байерецкого автономный округ'),
#  ('_', 'оффальных платёжный система'),
#  ('_', 'следственный комитет'),
#  ('_', 'славянский управление'),
#  ('_', 'тур'),
#  ('_', 'мультимедицинскую программа'),
#  ('мочь быть', 'мочь быть'),
#  ('_', 'ружный хоккейный израиль'),
#  ('строительство', 'строительство'),
#  ('_', 'митя чемпион'),
#  ('_', 'государственный тайна'),
#  ('_', 'анатолий академов'),
#  ('_', 'хаты-мансийского автономный округ'),
#  ('_', 'антитеррористический комитет'),
#  ('_', 'авиационный комплекс'),
#  ('_', 'александр лютовым'),
#  ('_', 'ибрагим'),
#  ('_', 'еврейский автономный война'),
#  ('_', 'агентство по борьба с экономический преступление'),
#  ('_', 'пенсионный фонд'),
#  ('_', 'главное следственный управление'),
#  ('_', 'сам авиационный комплекс'),
#  ('северный ледовитый океан', 'северный ледовитый океан'),
#  ('_', 'федеральный антимонопольный служба'),
#  ('_', 'соединить штат америка'),
#  ('_', 'соединить штат америка'),
#  ('период', 'период'),
#  ('_', 'автоматический система изучение общественный мнение'),
#  ('_', 'тягневосточный региональный округ'),
#  ('_', 'киберных защита'),
#  ('_', 'лига чемпион'),
#  ('_', 'видеостанцию'),
#  ('_', 'стороженко'),
#  ('миллион', 'миллион'),
#  ('_', 'информационный агентство'),
#  ('_', 'информационный агентство'),
#  ('_', 'эллипецкого автономный округ'),
#  ('_', 'родовой отечественный'),
#  ('_', 'видеообзор'),
#  ('_', 'управление по борьба с экономический преступление'),
#  ('миллиард', 'миллиард'),
#  ('_', 'беспилотный летательный аппарат'),
#  ('_', 'государственный университет'),
#  ('_', 'соединить штат америка'),
#  ('_', 'анатолий касьянов'),
#  ('_', 'тихоокеанский региональный округ'),
#  ('_', 'рынок ценный технология'),
#  ('_', 'международный валютный фонд'),
#  ('_', 'международный валютный фонд'),
#  ('_', 'рсфср федерация'),
#  ('_', 'китай'),
#  ('_', 'каравинского автономный округ'),
#  ('капитан', 'капитан'),
#  ('« интерфакс »', '« интерфакс »'),
#  ('_', 'макаров'),
#  ('_', 'центральный управление украинский националист'),
#  ('_', 'федеральный антимонопольный служба'),
#  ('информация', 'информация'),
#  ('_', 'соединить штат америка'),
#  ('_', 'новосибирск'),
#  ('_', 'самоуправляющий компания'),
#  ('_', 'соединить штат америка'),
#  ('_', 'хельсинкский автономный округ'),
#  ('_', 'санкской область'),
#  ('_', 'международный союз конькобежец'),
#  ('миллиард', 'миллиард'),
#  ('_', 'стектор военный суд'),
#  ('_', 'национальный баскетбольный ассоциация'),
#  ('_', 'санецкого автономный суд'),
#  ('_', 'курдский автономный колония'),
#  ('_', 'биография'),
#  ('_', 'чемпионат мир'),
#  ('_', 'государственный университет'),
#  ('_', 'девятимесячный'),
#  ('_', 'национальный антимонопольный служба'),
#  ('_', 'европейский окружный военный суд'),
#  ('_', 'информационный агентство'),
#  ('_', 'ввп'),
#  ('_', 'китайский региональный агентство'),
#  ('миллиард', 'миллиард'),
#  ('километр', 'километр'),
#  ('_', 'зелезного вода'),
#  ('_', 'хави-васо'),
#  ('_', 'черноморский флот'),
#  ('квартира', 'квартира'),
#  ('_', 'соединить штат америка'),
#  ('_', 'церковь христос спаситель'),
#  ('_', 'рынковского автономный округ'),
#  ('_', 'ритуционного рынок'),
#  ('миллион', 'миллион'),
#  ('республиканский управление', 'региональный управление'),
#  ('_', 'российский федерация'),
#  ('_', 'технический сотрудничество'),
#  ('_', 'международный центр новость'),
#  ('сентябрь', 'сентябрь'),
#  ('_', 'дотецкий автономный комитет'),
#  ('ассоциация', 'ассоциация'),
#  ('_', 'игнат украина'),
#  ('_', 'фсб федерация'),
#  ('информация', 'информация'),
#  ('_', 'ассоциация по безопасность'),
#  ('километр', 'километр'),
#  ('_', 'федеральный агентство'),
#  ('информация', 'информация'),
#  ('_', 'соединить штат америка'),
#  ('_', 'порноактеров'),
#  ('_', 'рабочий партия'),
#  ('_', 'европейский банк реконструкция и развитие'),
#  ('_', 'хоспиталь'),
#  ('_', 'хохоккея россия'),
#  ('_', 'международный антидопинговый агентство'),
#  ('_', 'марадон'),
#  ('_', 'гуанд'),
#  ('_', 'морской оборона'),
#  ('_', 'верховный суд'),
#  ('верховный рада', 'верховный рада'),
#  ('конституционный суд', 'конституционный суд'),
#  ('_', 'верховный главнокомандующий'),
#  ('номер', 'номер'),
#  ('_', 'ханты-мансийский автономный округ'),
#  ('_', 'карабахский республика'),
#  ('_', 'автоматический окружный военный суд'),
#  ('_', 'соединить штат америка'),
#  ('генеральный консульство', 'генеральный консульство'),
#  ('_', 'жирный амур'),
#  ('_', 'капитан'),
#  ('_', 'понадобиться'),
#  ('_', 'пожизненный лишение свобода'),
#  ('_', 'хорбитражный суд'),
#  ('_', 'ассоциация теннисистов-профессионалов'),
#  ('_', 'гаранова'),
#  ('_', 'южный административный округ'),
#  ('_', 'диабет'),
#  ('_', 'порт'),
#  ('капитан', 'капитан'),
#  ('_', 'главное следственный управление'),
#  ('_', 'дорожно-транспортный происшествие'),
#  ('не быть', 'не быть'),
#  ('_', 'организация объединить нация'),
#  ('_', 'соединить штат америка'),
#  ('_', 'габанова'),
#  ('_', 'сало арабский республика'),
#  ('_', 'западный уголовный криз'),
#  ('_', 'габы-мансийского автономный округ'),
#  ('_', 'федеральный агентство по безопасность'),
#  ('_', 'сексистую порнография'),
#  ('_', 'гибдд'),
#  ('_', 'кулаевым авиационный комитет'),
#  ('_', 'городской государственный экситет'),
#  ('_', 'сильвион'),
#  ('информация', 'информация'),
#  ('_', 'федеральный служба по тариф'),
#  ('_', 'спасательный корабль'),
#  ('_', 'законодательный собрание'),
#  ('_', 'куинецкий автономный округ'),
#  ('_', 'безопасный вещество'),
#  ('_', 'национальный баскетбольный ассоциация'),
#  ('_', 'дтп'),
#  ('_', 'павлий касьянов'),
#  ('_', 'законодательный собрание оон'),
#  ('_', 'следственный комитет'),
#  ('_', 'уголовный розукцию'),
#  ('_', 'приморский край'),
#  ('_', 'патриархат'),
#  ('_', 'ханты-мансийский автономный округ'),
#  ('_', 'ханты-мансийский автономный округ'),
#  ('_', 'послематчевая'),
#  ('международный', 'международный'),
#  ('_', 'управление по борьба с экономический преступление'),
#  ('_', 'тихоокеанский региональный телескоп'),
#  ('_', 'сторожевой телескоп'),
#  ('_', 'николай'),
#  ('_', 'андрей'),
#  ('_', 'гельсинкском автономный округ'),
#  ('миллион', 'миллион'),
#  ('_', 'информационный агентство'),
#  ('_', 'нефтеперерабатывающий завод'),
#  ('_', 'госпиталь'),
#  ('февраль', 'февраль'),
#  ('_', 'джордж израиль'),
#  ('_', 'госпиталь'),
#  ('_', 'бюро по безопасность'),
#  ('стена', 'снайпер'),
#  ('_', 'пресс-конференция'),
#  ('фестиваль', 'фестиваль'),
#  ('_', 'бюро по безопасность'),
#  ('_', 'пожизненный лишение свобода'),
#  ('_', 'федеральный агентство'),
#  ('_', 'московский городской избирательный комитет'),
#  ('_', 'соединить штат америка'),
#  ('учебный центр', 'учебный центр'),
#  ('_', 'почтовый связь'),
#  ('_', 'вольфган'),
#  ('_', 'ввп'),
#  ('_', 'андрей'),
#  ('_', 'соединить штат америка'),
#  ('_', 'медиазоне'),
#  ('_', 'всемирный антидопинговый комитет'),
#  ('_', 'матерский автономный округ'),
#  ('_', 'сабакова'),
#  ('_', 'кыргызстан'),
#  ('_', 'михаил касьянов'),
#  ('_', 'сабинский автономный округ'),
#  ('километр', 'километр'),
#  ('_', 'сверхзвуковой'),
#  ('_', 'криопольный фонд'),
#  ('_', 'служба безопасность'),
#  ('_', 'лустовой академия наука'),
#  ('_', 'антитеррористический отход'),
#  ('_', 'экономический партия'),
#  ('_', 'канаральная антимонопольный служба'),
#  ('_', 'городской административный управление'),
#  ('_', 'северный корея'),
#  ('_', 'зелёный крест'),
#  ('_', 'тур'),
#  ('_', 'порт'),
#  ('_', 'академия чемпион'),
#  ('_', 'московский автономный округ'),
#  ('_', 'кузовецкий автономный округ'),
#  ('_', 'капитан'),
#  ('_', 'хоккейный клуб'),
#  ('_', 'эрабет'),
#  ('_', 'хонтбольный союз'),
#  ('информация', 'информация'),
#  ('_', 'чрезвычайный происшествие'),
#  ('_', 'международный организация'),
#  ('_', 'мид'),
#  ('_', 'система безопасность'),
#  ('_', 'андрей'),
#  ('сентябрь', 'сентябрь'),
#  ('_', 'макаров'),
#  ('_', 'мид'),
#  ('_', 'торговый палата'),
#  ('_', 'европейский союз'),
#  ('_', 'соединить штат америка'),
#  ('_', 'род'),
#  ('_', 'профессиональный медицинский страхование'),
#  ('_', 'томоновский автономный округ'),
#  ('_', 'национальный телевидение'),
#  ('_', 'антонов'),
#  ('южный корея', 'южный корея'),
#  ('_', 'матерский автономный округ'),
#  ('_', 'сила оборона украина'),
#  ('_', 'информационный агентство'),
#  ('_', 'канецкий автономный суд'),
#  ('_', 'украинский информация'),
#  ('_', 'хоккейный клуб'),
#  ('_', 'крылатый хоккейный лига'),
#  ('февраль', 'февраль'),
#  ('_', 'хоккейный клуб'),
#  ('_', 'пользователь'),
#  ('сентябрь', 'сентябрь'),
#  ('_', 'no3'),
#  ('_', 'сибирский региональный управление'),
#  ('_', 'михаил касьянов'),
#  ('_', 'соединить штат америка'),
#  ('_', 'черепецкий военный суд'),
#  ('_', 'авиационный инвестиционный проект'),
#  ('_', 'паннопольный военный округ'),
#  ('_', 'пивоваренный компания'),
#  ('_', 'медицинский заключение'),
#  ('« интерфакс »', '« интерфакс »'),
#  ('не быть', 'не быть'),
#  ('_', 'фронтовый мена'),
#  ('_', 'мэтт тимошенко'),
#  ('_', 'российский федерация'),
#  ('_', 'главное следственный управление'),
#  ('_', 'российский федерация'),
#  ('_', 'международный агентство по атомный энергия'),
#  ('ядерный оружие', 'ядерный оружие'),
#  ('_', 'ханты-мансийский автономный округ'),
#  ('_', 'единый россия'),
#  ('_', 'мид'),
#  ('_', 'исламско-автономный суд'),
#  ('_', 'башмекерская контора'),
#  ('_', 'международный союз футбольный ассоциация'),
#  ('_', 'служба безопасность'),
#  ('_', 'уголовный розыск'),
#  ('_', 'чрезвычайный ситуация'),
#  ('_', 'торговый центр'),
#  ('_', 'патриархия'),
#  ('_', 'казнефтегаз'),
#  ('_', 'федеральный антимонопольный служба'),
#  ('_', 'федеральный антимонопольный служба'),
#  ('_', 'правило дорожный движение'),
#  ('_', 'бернард'),
#  ('_', 'корякский автономный округ'),
#  ('_', 'калькуя тимошенко'),
#  ('_', 'инвестиционный компания'),
#  ('конвой', 'конвой'),
#  ('_', 'квартира'),
#  ('_', 'государственный служба'),
#  ('_', 'академия наука'),
#  ('_', 'европейский центральный банк'),
#  ('_', 'европейский центральный банк'),
#  ('_', 'союз биатлонист россия'),
#  ('_', '« российский железный дорога »'),
#  ('_', '« российский железный дорога »'),
#  ('_', '« российский железный дорога »'),
#  ('_', 'джек поттер'),
#  ('_', 'маккейный лод'),
#  ('_', 'демократический партия украина'),
#  ('_', 'промышленный утлетом'),
#  ('_', 'национальный телескоп'),
#  ('_', 'служба судебный пристав'),
#  ('_', 'цска россия'),
#  ('_', 'лукановского крыло совет'),
#  ('_', 'эдуард'),
#  ('_', 'джек оон'),
#  ('_', 'сэм поттер'),
#  ('_', 'сэм сейтса'),
#  ('_', 'оливер оон'),
#  ('_', 'порностной компания'),
#  ('_', 'ливонная тимошенко'),
#  ('_', 'экипаж'),
#  ('_', 'соединить штат америка'),
#  ('московский', 'московский'),
#  ('_', 'европейский союз писатель'),
#  ('_', 'информационный агентство'),
#  ('_', 'мультиплеточных телефон'),
#  ('_', 'блок правый тимошенко'),
#  ('_', 'яценюк'),
#  ('_', 'европейский майдан'),
#  ('_', 'выставка'),
#  ('автоматизация', 'автоматизация'),
#  ('_', 'цифровой излучение'),
#  ('общественный палата', 'общественный палата'),
#  ('_', 'региональный управление'),
#  ('февраль', 'февраль'),
#  ('информация', 'информация'),
#  ('_', 'сибирский региональный управление'),
#  ('_', 'сибирский региональный управление'),
#  ('стандарт', 'стандарт'),
#  ('_', 'администрация президент'),
#  ('_', 'авиационный система'),
#  ('_', 'автоматизация'),
#  ('_', 'ханты-мансийский автономный округ'),
#  ('_', 'государственный предприятие'),
#  ('_', 'кинопроект'),
#  ('_', 'буркина-фасо'),
#  ('международный', 'международный'),
#  ('_', 'ханты-мансийский автономный округ'),
#  ('_', 'берлинский государственный университет'),
#  ('_', '« российский союз »'),
#  ('_', 'информационный агентство'),
#  ('_', 'киотский протокол'),
#  ('_', 'эдуард штотса'),
#  ('_', 'эмират'),
#  ('пресс-конференция', 'пресс-конференция'),
#  ('_', 'северный корея'),
#  ('_', 'воздушно-космический агентство'),
#  ('_', 'информационный агентство'),
#  ('_', 'главное следственный управление'),
#  ('_', 'система управление новость'),
#  ('_', 'фотостанцию'),
#  ('_', 'венеральный металлургический комбинат'),
#  ('_', 'слово крыло совет'),
#  ('_', 'китайско-тихоокеанский регион'),
#  ('_', 'венский автономный область'),
#  ('_', 'чеченский республика'),
#  ('_', 'польша космический станция'),
#  ('_', 'европейский союз футбольный ассоциация'),
#  ('_', 'тайна-мансийский автономный округ'),
#  ('_', 'автоматический межпланетный станция'),
#  ('_', 'украинский автономный система'),
#  ('_', 'российский футбольный премьер-лига'),
#  ('_', 'курановский автономный округ'),
#  ('_', 'московский городской центр'),
#  ('_', 'шрайонная больница'),
#  ('_', 'национальный эшекер'),
#  ('совет безопасность рф', 'совет безопасность оон'),
#  ('_', 'административный правонарушение'),
#  ('_', 'черноморский флот'),
#  ('_', 'федерация футбольный ассоциация'),
#  ('_', 'гол'),
#  ('_', 'информационный агентство'),
#  ('_', 'кодекс о административный правонарушение'),
#  ('информация', 'информация'),
#  ('_', 'всемирный экономический банк'),
#  ('_', 'министерство иностранный дело'),
#  ('_', 'агентство по безопасность'),
#  ('_', 'дипломатический миссия'),
#  ('_', 'информационный агентство'),
#  ('_', 'андрей'),
#  ('_', 'чеченский республика'),
#  ('« интерфакс »', '« интерфакс »'),
#  ('береговой охрана', 'береговой охрана'),
#  ('_', 'береговой охрана'),
#  ('_', 'ходненского автономный округ'),
#  ('_', 'государственный дума'),
#  ('_', 'российский энергетический агентство'),
#  ('_', 'международный авиационный комитет'),
#  ('пивоваренный компания', 'пресс-конференция'),
#  ('_', 'сточный телефон'),
#  ('_', 'шигурный установка'),
#  ('_', 'фотоблогатов'),
#  ('_', 'московский нефтепровод'),
#  ('_', 'нхл'),
#  ('_', 'казянский автономный округ'),
#  ('_', 'единый частный партнёрство'),
#  ('ассоциация теннисистов-профессионалов',
#   'ассоциация теннисистов-профессионалов'),
#  ('информация', 'информация'),
#  ('_', 'чувашов'),
#  ('_', 'блэку'),
#  ('_', 'нато'),
#  ('_', 'порт'),
#  ('_', 'тихоокеанский флот'),
#  ('_', 'нато'),
#  ('вертолёт', 'вертолёт'),
#  ('вертолёт', 'вертолёт'),
#  ('миллион', 'миллион'),
#  ('дипломатический представительство', 'дипломатический представительство'),
#  ('_', 'южный административный кодекс'),
#  ('_', 'джо поттер'),
#  ('_', 'ссср'),
#  ('_', 'авиационный комплекс'),
#  ('« интерфакс »', '« интерфакс »'),
#  ('_', 'вид на жительство'),
#  ('вертолёт', 'вертолёт'),
#  ('_', 'федеральный антимонопольный служба'),
#  ('исправительный колония', 'исправительный колония'),
#  ('_', 'страховой страхаций'),
#  ('_', 'лондонский академия наука'),
#  ('миллион', 'миллион'),
#  ('миллион', 'миллион'),
#  ('_', 'автономный стат'),
#  ('арбитражный суд', 'арбитражный суд'),
#  ('_', 'туристический тур'),
#  ('_', 'всемирный антидопинговый агентство'),
#  ('_', 'антимонопольный служба'),
#  ('_', 'министерство иностранный дело'),
#  ('_', 'залецкий автономный округ'),
#  ('_', 'управление внутренний дело'),
#  ('_', 'информационный агентство'),
#  ('миллиметр', 'миллиметр'),
#  ('_', 'драгоценный металл'),
#  ('_', 'эобанк реконструкция и развитие'),
#  ('_', 'командир рота'),
#  ('_', 'линкационного телефон'),
#  ('_', 'ханты-мансийский автономный округ'),
#  ('эпицентр', 'эпицентр'),
#  ('_', 'колумбия'),
#  ('_', 'комсомольск-на-амуре'),
#  ('номер', 'номер'),
#  ('ассоциация теннисистов-профессионалов',
#   'ассоциация теннисистов-профессионалов'),
#  ('_', 'торбитражный суд'),
#  ('_', 'федеральный антимонопольный служба'),
#  ('_', 'соединить штат америка'),
#  ('_', 'архангельский область'),
#  ('километр', 'километр'),
#  ('_', 'ханты-мансийский автономный округ'),
#  ('_', 'ивановский область'),
#  ('_', 'блок безопасность россия'),
#  ('_', 'командир рота'),
#  ('миллион', 'миллион'),
#  ('_', 'информационный агентство'),
#  ('_', 'точный матч'),
#  ('_', 'пластический топливо'),
#  ('_', 'полиция безопасность'),
#  ('_', 'главное следственный управление'),
#  ('_', 'главное следственный управление'),
#  ('_', 'нанометр'),
#  ('_', 'владительстве компания'),
#  ('_', 'международный баскетбольный союз'),
#  ('_', 'союз журналист россия'),
#  ('_', 'верховный суд оон'),
#  ('_', 'национальный баскетбольный ассоциация'),
#  ('_', 'служба безопасность'),
#  ('_', 'сша'),
#  ('_', 'национальный банк украина'),
#  ('_', 'криптовалюты'),
#  ('_', 'битоговина'),
#  ('_', 'чудославный'),
#  ('московский', 'московский'),
#  ('_', 'тур'),
#  ('_', 'гол'),
#  ('_', 'служба безопасность'),
#  ('_', 'федеральный агентство по безопасность'),
#  ('европейский союз', 'европейский союз'),
#  ('миллион', 'миллион'),
#  ('_', 'мазецкий автономный округ'),
#  ('федеральный антимонопольный служба', 'федеральный антимонопольный служба'),
#  ('_', 'федеральный антимонопольный служба'),
#  ('_', 'герой советский союз'),
#  ('_', 'матерский автономный суд'),
#  ('_', 'матерский автономный суд'),
#  ('_', 'матерский автономный округ'),
#  ('_', 'операционный система'),
#  ('_', 'сотовый телефон'),
#  ('_', 'московский городской совет'),
#  ('_', 'дерянский автономный округ'),
#  ('_', 'холомлевском автономный округ'),
#  ('_', 'следственный комитет'),
#  ('_', 'антитеррористический комитет'),
#  ('_', 'нормекерском контора'),
#  ('_', 'украинский оборонный природный ресурс'),
#  ('совет федерация', 'совет федерация'),
#  ('_', 'шкуратур'),
#  ('_', 'монопольный служба'),
#  ('« интерфакс »', '« интерфакс »'),
#  ('_', 'командир рота'),
#  ('сентябрь', 'сентябрь'),
#  ('_', 'разведывательный управление'),
#  ('миллиард', 'миллиард'),
#  ('_', 'видеосервис'),
#  ('_', 'видеопортал'),
#  ('_', 'соединить штат америка'),
#  ('_', 'советский союз'),
#  ('_', 'советский союз'),
#  ('_', 'служба судебный пристав'),
#  ('_', 'европейский банк реконструкция и развитие'),
#  ('информация', 'информация'),
#  ('_', 'федеральный антимонопольный служба'),
#  ('_', 'чемпионат мир'),
#  ('_', 'туристический отход'),
#  ('_', 'федеральный антимонопольный служба'),
#  ('_', 'дополнительный освобождение полезный ископаемое'),
#  ('_', 'предприниматель'),
#  ('_', 'федеральный агентство'),
#  ('вертолёт', 'вертолёт'),
#  ('_', 'вадового административный округ'),
#  ('_', 'беспилотный летательный аппарат'),
#  ('_', 'образовательный учреждение украина'),
#  ('_', 'витарский автономный округ'),
#  ('_', 'совет национальный безопасность'),
#  ('_', 'матерского автономный округ'),
#  ('февраль', 'февраль'),
#  ('_', 'российский банк россия'),
#  ('_', 'центральный банк'),
#  ('миллион', 'миллион'),
#  ('_', 'европейский банк реконструкция и развитие'),
#  ('_', 'международный суд оон'),
#  ('сентябрь', 'сентябрь'),
#  ('_', 'гол'),
#  ('_', 'макаров'),
#  ('_', 'гигагерц'),
#  ('саудовский аравия', 'саудовский аравия'),
#  ('_', 'единый энергетический отход'),
#  ('_', 'административный правонарушение'),
#  ('жилой дом', 'жилой дом'),
#  ('_', 'российский федерация'),
#  ('_', 'инвестиционный проект'),
#  ('_', 'нхл'),
#  ('_', 'лисицкий автономный округ'),
#  ('_', 'ханты-мансийский автономный округ'),
#  ('университет', 'университет'),
#  ('_', 'видеозвонок'),
#  ('информация', 'информация'),
#  ('_', 'профессиональный педагогический университет'),
#  ('информация', 'информация'),
#  ('миллион', 'миллион'),
#  ('_', 'валерий касьянов'),
#  ('_', 'союз журналист россия'),
#  ('_', 'нокаут'),
#  ('петербург', 'петербург'),
#  ('_', 'государственный университет'),
#  ('_', 'союз биатлонист россия'),
#  ('_', 'союз биатлонист россия'),
#  ('_', 'куяновский автономный округ'),
#  ('_', 'союз биатлонист россия'),
#  ('_', 'кубок украина'),
#  ('_', 'федеральный агентство'),
#  ('не быть', 'не быть'),
#  ('_', 'марина касьянов'),
#  ('_', 'пол'),
#  ('информация', 'информация'),
#  ('сентябрь', 'сентябрь'),
#  ('_', 'стабилизационный'),
#  ('федеральный резервный система', 'федеральный резервный система'),
#  ('_', 'морской войско'),
#  ('_', 'главное следственный управление'),
#  ('_', 'стабилизационный'),
#  ('_', 'джек поттер'),
#  ('фестиваль', 'фестиваль'),
#  ('сентябрь', 'сентябрь'),
#  ('_', 'монография'),
#  ('_', 'мусламским партнёрство'),
#  ('_', 'бутылевского автономный суд'),
#  ('_', 'государственный авиационный союз'),
#  ('_', 'информационный агентство'),
#  ('_', 'уголовный розыск'),
#  ('_', 'ассоциация'),
#  ('_', 'тур'),
#  ('февраль', 'февраль'),
#  ('_', 'еврейский автономный область'),
#  ('_', 'институт международный отношение'),
#  ('лига чемпион', 'лига чемпион'),
#  ('_', 'федеральный агентство'),
#  ('_', 'следственный комитет'),
#  ('_', 'координационный совет'),
#  ('_', 'лобовой окружный военный суд'),
#  ('_', 'венеральной автономный служба'),
#  ('_', 'тихоокеанский флот'),
#  ('« интерфакс »', '« интерфакс »'),
#  ('_', 'кинологический служба'),
#  ('футбольный клуб', 'футбольный клуб'),
#  ('_', 'федерация национальный лига'),
#  ('новосибирск', 'новосибирск'),
#  ('_', 'кержного военный управление'),
#  ('_', 'медицинский брат'),
#  ('_', 'чаловая крылатый'),
#  ('_', 'казицкого автономный округ'),
#  ('_', 'туристический установка'),
#  ...]
