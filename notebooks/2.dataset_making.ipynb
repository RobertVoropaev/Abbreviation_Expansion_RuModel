# %% [markdown]
# # 2. Сборка датасета

# %%
import os
import sys
import random
import pickle

import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

from tqdm import tqdm
from pandarallel import pandarallel
from collections import Counter

import pymorphy2
import nltk

from sklearn.model_selection import train_test_split

from ipymarkup         import show_box_markup
from ipymarkup.palette import palette, PALETTE, BLUE, RED, GREEN, PURPLE, BROWN, ORANGE

SEED = 1
random.seed(SEED)

pd.set_option('display.max_colwidth', 255)
tqdm.pandas()
pandarallel.initialize(progress_bar=True, nb_workers=14, use_memory_fs=False)

sys.path.append("..")
from src import *
# Out:
# INFO: Pandarallel will run on 14 workers.
# INFO: Pandarallel will use standard multiprocessing data transfer (pipe) to transfer data between the main process and workers.

# %% [markdown]
# ## 1. Загрузка данных

# %%
abbr = pd.read_csv("../data/abbr.csv")
lenta = pd.read_csv("../data/lenta.csv")

# %% [markdown]
# ## Замена явных сокращений в текстках

# %%
abbr_counter = abbr.groupby("abbr_norm").size()
explicit_abbr = abbr_counter[abbr_counter == 1].index.to_list()

explicit_dict = abbr[abbr["abbr_norm"].isin(explicit_abbr)]
explicit_dict = dict(explicit_dict[["abbr_norm", "desc_norm"]].values)

# %%
def replace_by_dict(line):
    for k, v in explicit_dict.items():
        line = line.replace(f" {k} ", f" {v} ")
    return line

lenta["text_norm"] = lenta["text_norm"].parallel_apply(replace_by_dict)
# Out:
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=36019), Label(value='0 / 36019')))…

# %% [markdown]
# ## 2. Построение дерева сокращений

# %%
class AbbrInfo:
    def __init__(self, abbr_id, abbr, abbr_count):
        self.abbr_id = abbr_id 
        self.abbr = abbr
        self.abbr_count = abbr_count

ABBR_LIST_KEY = "<ABBR_LIST_KEY>"
        
def create_abbr_tree(abbr, abbr_list_key = ABBR_LIST_KEY):        
    tree = {}
    for norm_desc, norm_abbr, abbr_id, abbr_count in abbr[["desc_norm", 
                                                           "abbr_norm", 
                                                           "abbr_id", 
                                                           "abbr_count"]].values:
        words = norm_desc.split(" ")

        curr_tree = tree
        for word in words:
            if word not in curr_tree:
                curr_tree[word] = {}
            curr_tree = curr_tree[word]


        if abbr_list_key not in curr_tree:
            curr_tree[abbr_list_key] = []

        curr_tree[abbr_list_key].append(AbbrInfo(abbr_id, norm_abbr, abbr_count))
    return tree

# %%
abbr_tree = create_abbr_tree(abbr)
abbr_tree["министерство"]
# Out:
# {'оборона': {'украина': {'<ABBR_LIST_KEY>': [<__main__.AbbrInfo at 0x7f55011fa5b0>]},
#   '<ABBR_LIST_KEY>': [<__main__.AbbrInfo at 0x7f5500564340>]},
#  'внутренний': {'безопасность': {'<ABBR_LIST_KEY>': [<__main__.AbbrInfo at 0x7f55012297c0>]},
#   'дело': {'<ABBR_LIST_KEY>': [<__main__.AbbrInfo at 0x7f55005cda00>]}},
#  'иностранный': {'дело': {'<ABBR_LIST_KEY>': [<__main__.AbbrInfo at 0x7f55011e7520>,
#     <__main__.AbbrInfo at 0x7f55011e7580>]}},
#  'строительство': {'<ABBR_LIST_KEY>': [<__main__.AbbrInfo at 0x7f55011e7b80>]},
#  'транспорт': {'<ABBR_LIST_KEY>': [<__main__.AbbrInfo at 0x7f55011e7f40>]},
#  'здравоохранение': {'<ABBR_LIST_KEY>': [<__main__.AbbrInfo at 0x7f55005fc5e0>]},
#  'энергетика': {'<ABBR_LIST_KEY>': [<__main__.AbbrInfo at 0x7f55005bd6a0>]},
#  'национальный': {'безопасность': {'<ABBR_LIST_KEY>': [<__main__.AbbrInfo at 0x7f5500564580>]}}}

# %% [markdown]
# ## 3. Получение меток для токенов

# %%
def choice_abbr(abbr_list: list, 
                weighted_choice: bool = True, 
                add_to_zeros: float = 0):
    abbr_counts = []
    
    if weighted_choice:
        for abbr_info in abbr_list:
            cnt = abbr_info.abbr_count
            if cnt == 0:
                cnt = add_to_zeros
            abbr_counts.append(cnt)
    else:
        abbr_counts = None
    
    
    return random.choices(abbr_list, weights=abbr_counts, k=1)[0]

# %%
OUTSIDE_LABEL = "_"
BEGIN_LABEL = "B"
END_LABEL = "E"
INSIDE_LABEL = "I"
ONE_WORD_LABEL = "W"

def get_text_labels(text, 
                    abbr_tree, 
                    weighted_choice: bool = None, 
                    add_to_zeros: float = None):
    text = text.split(" ")
    labels = [OUTSIDE_LABEL for i in range(len(text))]

    curr_node = abbr_tree
    desc_start = None

    word_i = 0
    while word_i < len(text):
        curr_i = word_i
        while curr_i < len(text) and text[curr_i] in curr_node:
            curr_node = curr_node[text[curr_i]]
            curr_i += 1

        if ABBR_LIST_KEY in curr_node: 

            abbr_id = choice_abbr(curr_node[ABBR_LIST_KEY], weighted_choice, add_to_zeros).abbr_id

            labels[word_i] = f"{BEGIN_LABEL}-{abbr_id}"
            for j in range(word_i + 1, curr_i - 1): 
                labels[j] = f"{INSIDE_LABEL}-{abbr_id}"
            labels[curr_i - 1] = f"{END_LABEL}-{abbr_id}"

            if word_i == curr_i - 1:
                labels[word_i] = f"{ONE_WORD_LABEL}-{abbr_id}"

            word_i = curr_i - 1

        curr_node = abbr_tree
        word_i += 1
    return " ".join(labels)

get_text_labels(lenta.text_norm.iloc[0], abbr_tree)
# Out:
# '_ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ W-308 _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ W-961 _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ W-308 _ _ _'

# %%
def show_markup(recipe,  tags, use_abbr: bool = True):
    mapper = lambda tag: tag[2:] if "-" in tag else tag
    
    tags  = [mapper(tag) for tag in tags]
    text  = ' '.join(recipe)
    spans = []
        
    start, end, tag = 0, len(recipe[0]), tags[0]
    
    for word, ttag in zip(recipe[1:], tags[1:]): 
        
        if tag == ttag:
            end  += 1 + len(word)
            
        else:
            span  = (start, end, tag)
            spans.append(span)
        
            start = 1 + end
            end  += 1 + len(word)
            
            if ttag != "_":
                if use_abbr:
                    label = abbr[abbr.abbr_id == int(ttag)].abbr_norm.iloc[0]
                else:
                    label = abbr[abbr.abbr_id == int(ttag)].desc_norm.iloc[0]
                ttag = label + f" ({ttag})"
            tag   = ttag
            
    span  = (start, end, tag)
    spans.append(span)        
            
    show_box_markup(text, spans)

# %%
text = lenta.text_norm.iloc[22]
labels = get_text_labels(text, abbr_tree)

show_markup(text.split(" "), labels.split(" "))
# Out:
# <div class="tex2jax_ignore" style="white-space: pre-wrap"><span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">десять американский турист и два житель танзания погибнуть в время авиакатастрофа самолёт cessna 404 в танзания . причина авария 14-местного самолёт называть плохой погода : по свидетельство очевидец , самолёт лететь над покрыть густой туман склон год мера , задеть за скрытый в туман дерево , потерять контроль и упасть . спасатель , прибыть на место падение самолёт , обнаружить , что в живой никто не остаться - тело пассажир и член экипаж быть буквально разорвать и разбросать в радиус 500 метр . полиция уже сообщить имя погибнуть житель танзания - это пилот кристофер перейра и туристический гид уильсон мейриали . имя десять погибнуть американец пока не сообщаться . спасательный операция быть осложнить тем , что самолёт упасть в густой лес , где даже невозможно посадить<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #64b5f6;">_</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #c8e6c9; background: #e8f5e9">вертолёт<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #66bb6a;">верт (1030)</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">. поэтому спасетелям прийтись идти 7 час пешком через лес до место падение . упавший самолёт направляться из<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #64b5f6;">_</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #ffcdd2; background: #ffebee">национальный<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #e57373;">нп (1147)</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #ffcdd2; background: #ffebee">парк<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #e57373;">нп (1147)</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">серенгети в<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #64b5f6;">_</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #ffe0b2; background: #fff3e0">международный<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #ffb74d;">мн (928)</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">аэропорт килиманджаро .<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #64b5f6;">_</span></span></div>

# %%
lenta["labels"] = lenta["text_norm"].parallel_apply(lambda x: get_text_labels(x, abbr_tree))
# Out:
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=36019), Label(value='0 / 36019')))…

# %% [markdown]
# ## 4. Замена слов на сокращения

# %%
def replace_word_by_abbr(text, labels, abbr, p_replace: float = 0.2):
    text = text.split(" ")
    labels = labels.split(" ")
    
    new_text = []
    new_labels = []

    i = 0
    while i < len(text):
        label = labels[i]
        if label == OUTSIDE_LABEL:
            new_text.append(text[i])
            new_labels.append(OUTSIDE_LABEL)

        mode = label[0]

        if mode in [ONE_WORD_LABEL, BEGIN_LABEL]:
            abbr_id = int(label[2:])
            replaced = random.choices([False, True], weights=[(1 - p_replace), p_replace])[0]
            if replaced:
                norm_abbr = abbr[abbr.abbr_id == abbr_id].abbr_norm.iloc[0].split(" ")
                
                if len(norm_abbr) == 1:
                    new_text.append(norm_abbr[0])
                    new_labels.append(f"{ONE_WORD_LABEL}-{str(abbr_id)}")
                else:
                    new_text.append(norm_abbr[0])
                    new_labels.append(f"{BEGIN_LABEL}-{str(abbr_id)}")
                    for word in norm_abbr[1:-1]:
                        new_text.append(word)
                        new_labels.append(f"{INSIDE_LABEL}-{str(abbr_id)}")
                    new_text.append(norm_abbr[-1])
                    new_labels.append(f"{END_LABEL}-{str(abbr_id)}")

            while i < len(text) and labels[i] != OUTSIDE_LABEL and int(labels[i][2:]) == abbr_id:
                if not replaced:
                    new_text.append(text[i])
                    new_labels.append(OUTSIDE_LABEL)
                i += 1
        else:
            i += 1

    new_text = " ".join(new_text)
    new_labels = " ".join(new_labels)
    
    return pd.Series({"new_text": new_text, "new_labels": new_labels})

# %%
for i in range(10, 15):
    text = lenta.text_norm.iloc[i]
    labels = get_text_labels(text, abbr_tree)

    replaced_series = replace_word_by_abbr(text, labels, abbr)


    show_markup(replaced_series["new_text"].split(" "), 
                replaced_series["new_labels"].split(" "), 
                use_abbr=False)
# Out:
# <div class="tex2jax_ignore" style="white-space: pre-wrap"><span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">россия крайне негативно оценивать судебный процесс о `` январскихсобытиях 1991 год в вильнюс &#x27;&#x27; . напомнить , что речь идти о попытка<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #64b5f6;">_</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #d1c4e9; background: #ede7f6">госпереворот<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #9575cd;">государственный переворот (135)</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">в литва , заявить о свой независимость , когда властный орган объявить себя анонимный `` комитет национальный спасение &#x27;&#x27; , опираться на сила советский танк , ввести в этот день в литва с территория россия , и на спецподразделение советский армия , захватить , в частность , телецентр в вильнюс . другой противоборствующий сторона возглавляться лидер радикальный литовский националист , впоследствии президент литва витаусом ландсбергисом . столкновение на улица вильнюс сопровождаться больший количество человеческий жертва , фиксироваться на видеоплёнка , неоднократно показываться по центральный , а потом и российский , телевидение в качество пример пагубность имперский политика . теперь в литва пройти суд над участник событие , выступать на сторона советский войско . как заявить риа `` новость &#x27;&#x27; впосольстве российский федерация в этот страна , определённый сила в литва пытаютсяиспользовать этот политический процесс для тот , чтобы броситьтень на российско-литовские отношение . в результат завершиться здесь судебногоразбирательства к длительный срок заключение приговорить рядобщественных деятель литва , среди который 70-летний гражданинроссии станислав мицкевич , гражданин иванов и смоткин . `` решение вильнюсский суд не моглоне вызвать озабоченность российский общественность . `` - подчеркнуть в посольство . `` судебный процесс являться дело суверенный литва , однаков москва рассчитывать , что здравый смысл взять верх илитовские власть проявить гуманизм при окончательный решениисудьбы российский гражданин , здоровье который серьезноподорвано &#x27;&#x27; , отметить в посольство россия .<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #64b5f6;">_</span></span></div>
# <div class="tex2jax_ignore" style="white-space: pre-wrap"><span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">по сведение миссия<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #64b5f6;">_</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #d7ccc8; background: #efebe9">оон<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #a1887f;">организация объединить нация (53)</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">, передаваемый риа `` новость &#x27;&#x27; , в голосование по вопрос о самопределении бывший колония принять участие более 95 % зарегистрировать избиратель . подсчёт голос начаться в среда , он быть анонимный . сначала в присутствие свидетель быть вскрыть всё опечатать коробка , затем всё бюллетень быть перемешать , чтобы невозможно быть определить , откуда они поступить , и начаться подсчёт по принцип голосование весь избиратель на один участке.как сообщать риа `` новость &#x27;&#x27; , администрация клинтон отмечать `` чрезвычайный явка &#x27;&#x27; и `` успех &#x27;&#x27; провести в восточный тимор референдум по вопрос о независимость этот индонезийский провинция .<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #64b5f6;">_</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">сша<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #64b5f6;">соединить штат америка (903)</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">призывать весь участник признать результат референдум вне зависимость от исход голосование , сказать заместитель официальный представитель госдепартамент соединить штат америка джеймс фоули . указывать на случай насилие , отметить в время референдум , представитель госдепартамент подчеркнуть ответственность правительство индонезия за обеспечение порядок в время подсчёт голос и в последующий этап решение проблема восточный тимор .<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #64b5f6;">_</span></span></div>
# <div class="tex2jax_ignore" style="white-space: pre-wrap"><span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">соединить штат заплатить китай 4,5 миллион доллар в качество компенсация за бомбардировка китайский посольство в белград . в результат `` ошибочный &#x27;&#x27; натовский бомбардировка в май это год погибнуть три человек , 27 быть ранить . как передавать reuters , в вторник представитель посольство соединить штат америка в пекин сообщить , что `` на прошлый неделя вашингтон перевести 4,5 миллион доллар пострадать и семья погибнуть &#x27;&#x27; . сегодня советник госдепартамент соединить штат америка дэвид эндрюс завершить третий раунд переговоры с представитель министерство иностранный дело китай по повод компенсация за вред , нанести этот два страна посольство друг друг . самолёт нато разбомбить 7 май посольство китай в время налёт на югославия . в свой очередь разозлить китаец штурмовать американский представительство в пекин и тоже нанести он значительный ущерб . быть также поджечь дом<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #64b5f6;">_</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #c8e6c9; background: #e8f5e9">генконсул<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #66bb6a;">генеральный консул (715)</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">соединить штат америка в китайский город ченду . третий раунд переговоры закончиться без какой-либо конкретный результат . представитель посольство соединить штат америка не сообщить , какой именно компенсация два страна ждать друг от друг . пока неясно также , быть ли китай и далёкий требовать `` суровый наказание виновный &#x27;&#x27; . после трагический бомбардировка китай отказаться вести переговоры с соединить штат америка о вступление в<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #64b5f6;">_</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #ffcdd2; background: #ffebee">вто<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #e57373;">всемирный торговый организация (824)</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">( вто ) . и хотя<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #64b5f6;">_</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">сша<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #64b5f6;">соединить штат америка (903)</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">не раз выражать готовность возобновить обсуждение план китай по вступление в вто , китай по-прежнему неудовлетворённый `` извинение &#x27;&#x27; с сторона нато и считать , что бомбардировка посольство кнр в югославия быть намеренный .<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #64b5f6;">_</span></span></div>
# <div class="tex2jax_ignore" style="white-space: pre-wrap"><span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">скандал по повод `` отмывание деньга русский мафия &#x27;&#x27; , возникнуть первоначально вокруг американский bank of new york , расходиться всё более широкий круг . сейчас в он уже вовлечь международный валютный фонд , речь идти о участие десяток<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #64b5f6;">_</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #ffe0b2; background: #fff3e0">мн<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #ffb74d;">международный (928)</span></span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">банк в европа , юго-восточный азия , китай и так далее . что на сам дело стоить за весь это , быть видно в сам близкий будущее , - после выборы у мы и в `` ещё один большой страна &#x27;&#x27; , по выражение александр лившиц , специальный представитель президент российский федерация по связь с индустриально развитой страна . один из ответвление это скандал являться утверждение , что швейцарский строительный фирма mabetex замешать в обслуживание `` иностранный счёт &#x27;&#x27; семья ельцина.в баталия , развернуться в средство массовый информация вокруг этот утверждение , вступить и один из крупный итальянский газета la stampa . мы приводить полный перевод статья , опубликованнойв газета сегодня . паколли : дель понти предлагать я деньга<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #64b5f6;">_</span></span></div>
# <div class="tex2jax_ignore" style="white-space: pre-wrap"><span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">касаться на сегодняшний пресс-конференция обстановка в дагестан , министр внутренний дело российский федерация рушайло подчеркнуть , что в настоящий время там осуществляться второй этап операция - антитеррористический . `` ситуация нормальный , штатный , всё идти по план &#x27;&#x27; , - сказать он . подразделение объединить группировка федеральный сила , сообщать итар-тасс , завершить перегруппировка и полностью замкнуть кольцо окружение вокруг бандформирование религиозный экстремист в так называть кадарском анклав в дагестан . бой с исламист в район дагестанский сесть карамахи и чабанмахи принимать всё более ожесточённый характер и федеральный сила нести ощутимый потеря . они потерять два человек убитый и 29 раненый , экстремист удаться подбить 8 единица бронетехника . о потеря среди исламист ничего не сообщаться . сегодня по они позиция быть продолжить воздушный и артиллерийский удар . упорный характер бой , по мнение специалист , свидетельствовать о серьёзный подготовка боевик и они далеко идти план . вместе с тем возможность переговоры и исламист вовсе не исключаться . о это заявить итар-тасс председательгосударственного совет дагестан магомедали магомед . но переговоры возможный только на один условие - немедленный сдача весь оружие и восстановление на территория сесть конституционный порядок .<span style="vertical-align: middle; margin-left: 2px; font-size: 0.7em; color: #64b5f6;">_</span></span></div>

# %%
lenta[["text_new", "labels_new"]] = (
    lenta[["text_norm", "labels"]]
        .parallel_apply(lambda x: replace_word_by_abbr(x["text_norm"], x["labels"], 
                                                       abbr, p_replace=0.3), axis=1)
)
# Out:
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=36019), Label(value='0 / 36019')))…

# %% [markdown]
# ## Статистика

# %%
counter = Counter({})
for i in tqdm(range(lenta.shape[0])):
    counter += Counter(lenta["labels_new"].iloc[i].split(" "))
# Out:
# 100%|██████████| 504264/504264 [00:12<00:00, 41366.62it/s]

# %%
sorted(counter, key=lambda x: x[1])
# Out:
# [('W-150', 9),
#  ('W-974', 10),
#  ('W-227', 10),
#  ('W-226', 12),
#  ('W-870', 13),
#  ('W-845', 14),
#  ('W-846', 15),
#  ('W-21', 15),
#  ('W-698', 16),
#  ('W-74', 17),
#  ('W-719', 18),
#  ('W-718', 18),
#  ('W-185', 18),
#  ('W-712', 19),
#  ('W-73', 19),
#  ('W-781', 20),
#  ('W-797', 21),
#  ('W-696', 21),
#  ('W-418', 22),
#  ('W-184', 22),
#  ('W-510', 22),
#  ('W-727', 22),
#  ('W-13', 23),
#  ('W-350', 23),
#  ('W-75', 24),
#  ('W-417', 25),
#  ('W-459', 25),
#  ('W-189', 25),
#  ('W-354', 26),
#  ('W-458', 26),
#  ('W-259', 26),
#  ('W-425', 26),
#  ('W-647', 26),
#  ('W-32', 26),
#  ('W-954', 26),
#  ('W-694', 26),
#  ('W-532', 26),
#  ('W-1021', 27),
#  ('W-244', 27),
#  ('W-780', 27),
#  ('W-587', 27),
#  ('W-105', 27),
#  ('W-798', 28),
#  ('W-764', 28),
#  ('W-1086', 28),
#  ('W-630', 28),
#  ('W-710', 28),
#  ('W-191', 28),
#  ('W-421', 28),
#  ('W-594', 28),
#  ('W-155', 29),
#  ('W-1130', 29),
#  ('W-347', 29),
#  ('W-212', 29),
#  ('W-311', 30),
#  ('W-517', 30),
#  ('W-454', 30),
#  ('W-875', 30),
#  ('W-260', 30),
#  ('W-352', 30),
#  ('W-589', 30),
#  ('W-312', 30),
#  ('W-397', 30),
#  ('W-1027', 30),
#  ('W-310', 30),
#  ('W-907', 30),
#  ('W-803', 30),
#  ('W-947', 31),
#  ('W-676', 31),
#  ('W-14', 31),
#  ('W-455', 31),
#  ('W-601', 31),
#  ('W-1119', 31),
#  ('W-416', 31),
#  ('W-1033', 31),
#  ('W-1040', 32),
#  ('W-509', 32),
#  ('W-1105', 32),
#  ('W-990', 32),
#  ('W-921', 32),
#  ('W-786', 32),
#  ('W-684', 32),
#  ('W-943', 32),
#  ('W-473', 33),
#  ('W-859', 33),
#  ('W-724', 33),
#  ('W-67', 33),
#  ('W-685', 33),
#  ('W-1012', 33),
#  ('W-861', 33),
#  ('W-239', 33),
#  ('W-975', 33),
#  ('W-197', 33),
#  ('W-673', 33),
#  ('W-236', 34),
#  ('W-1109', 34),
#  ('W-876', 34),
#  ('W-900', 34),
#  ('W-978', 34),
#  ('W-763', 34),
#  ('W-817', 34),
#  ('W-792', 34),
#  ('W-444', 34),
#  ('W-460', 34),
#  ('W-498', 34),
#  ('W-983', 35),
#  ('W-598', 35),
#  ('W-794', 35),
#  ('W-674', 35),
#  ('W-409', 36),
#  ('W-464', 36),
#  ('W-174', 36),
#  ('W-937', 36),
#  ('W-878', 36),
#  ('W-1052', 36),
#  ('W-1066', 36),
#  ('W-785', 36),
#  ('W-168', 37),
#  ('W-1122', 37),
#  ('W-843', 37),
#  ('W-104', 37),
#  ('W-969', 37),
#  ('W-654', 37),
#  ('W-713', 37),
#  ('W-720', 37),
#  ('W-198', 37),
#  ('W-809', 37),
#  ('W-450', 38),
#  ('W-739', 38),
#  ('W-109', 38),
#  ('W-898', 38),
#  ('W-1124', 38),
#  ('W-635', 38),
#  ('W-294', 38),
#  ('W-108', 38),
#  ('W-139', 38),
#  ('W-83', 38),
#  ('W-533', 39),
#  ('W-882', 39),
#  ('W-468', 39),
#  ('W-552', 39),
#  ('W-234', 39),
#  ('W-404', 39),
#  ('W-726', 39),
#  ('W-1158', 39),
#  ('W-1042', 40),
#  ('W-706', 40),
#  ('W-837', 41),
#  ('W-1015', 41),
#  ('W-419', 41),
#  ('W-901', 41),
#  ('W-348', 41),
#  ('W-574', 41),
#  ('W-746', 41),
#  ('W-279', 41),
#  ('W-849', 41),
#  ('W-275', 41),
#  ('W-741', 41),
#  ('W-51', 42),
#  ('W-377', 42),
#  ('W-495', 42),
#  ('W-820', 42),
#  ('W-283', 42),
#  ('W-639', 42),
#  ('W-399', 42),
#  ('W-575', 42),
#  ('W-84', 42),
#  ('W-249', 42),
#  ('W-281', 42),
#  ('W-143', 42),
#  ('W-554', 42),
#  ('W-902', 42),
#  ('W-486', 43),
#  ('W-254', 43),
#  ('W-580', 43),
#  ('W-577', 43),
#  ('W-547', 43),
#  ('W-605', 43),
#  ('W-151', 43),
#  ('W-1133', 43),
#  ('W-85', 43),
#  ('W-192', 43),
#  ('W-722', 44),
#  ('W-1129', 44),
#  ('W-842', 44),
#  ('W-935', 44),
#  ('W-8', 44),
#  ('W-34', 44),
#  ('W-240', 44),
#  ('W-246', 44),
#  ('W-57', 44),
#  ('W-461', 44),
#  ('W-231', 44),
#  ('W-600', 45),
#  ('W-930', 45),
#  ('W-163', 45),
#  ('W-62', 45),
#  ('W-199', 45),
#  ('W-771', 45),
#  ('W-422', 45),
#  ('W-623', 45),
#  ('W-1041', 45),
#  ('W-813', 45),
#  ('W-757', 45),
#  ('W-1053', 45),
#  ('W-841', 45),
#  ('W-522', 45),
#  ('W-363', 46),
#  ('W-396', 46),
#  ('W-489', 46),
#  ('W-216', 46),
#  ('W-642', 46),
#  ('W-1152', 46),
#  ('W-556', 46),
#  ('W-200', 46),
#  ('W-102', 46),
#  ('W-584', 46),
#  ('W-1114', 46),
#  ('W-866', 46),
#  ('W-407', 46),
#  ('W-1118', 46),
#  ('W-1091', 46),
#  ('W-1049', 47),
#  ('W-836', 47),
#  ('W-637', 47),
#  ('W-599', 47),
#  ('W-47', 47),
#  ('W-137', 47),
#  ('W-390', 47),
#  ('W-591', 47),
#  ('W-431', 47),
#  ('W-1023', 47),
#  ('W-210', 47),
#  ('W-782', 47),
#  ('W-643', 47),
#  ('W-530', 48),
#  ('W-290', 48),
#  ('W-840', 48),
#  ('W-374', 48),
#  ('W-999', 48),
#  ('W-111', 48),
#  ('W-242', 48),
#  ('W-278', 48),
#  ('W-668', 48),
#  ('W-711', 49),
#  ('W-233', 49),
#  ('W-1108', 49),
#  ('W-758', 49),
#  ('W-721', 49),
#  ('W-56', 49),
#  ('W-203', 49),
#  ('W-420', 49),
#  ('W-801', 49),
#  ('W-596', 49),
#  ('W-172', 49),
#  ('W-940', 50),
#  ('W-503', 50),
#  ('W-373', 50),
#  ('W-86', 50),
#  ('W-487', 50),
#  ('W-256', 51),
#  ('W-117', 51),
#  ('W-162', 51),
#  ('W-506', 51),
#  ('W-799', 51),
#  ('W-228', 51),
#  ('W-451', 51),
#  ('W-360', 51),
#  ('W-331', 52),
#  ('W-640', 52),
#  ('W-800', 52),
#  ('W-1160', 52),
#  ('W-70', 52),
#  ('W-156', 52),
#  ('W-1022', 52),
#  ('W-1126', 53),
#  ('W-1137', 53),
#  ('W-828', 53),
#  ('W-38', 54),
#  ('W-582', 54),
#  ('W-576', 54),
#  ('W-37', 54),
#  ('W-941', 54),
#  ('W-140', 54),
#  ('W-1162', 54),
#  ('W-863', 54),
#  ('W-383', 55),
#  ('W-66', 55),
#  ('W-119', 55),
#  ('W-306', 56),
#  ('W-964', 56),
#  ('W-1085', 56),
#  ('W-776', 56),
#  ('W-737', 56),
#  ('W-220', 56),
#  ('W-1079', 56),
#  ('W-830', 57),
#  ('W-54', 57),
#  ('W-1143', 57),
#  ('W-541', 57),
#  ('W-505', 57),
#  ('W-744', 57),
#  ('W-292', 57),
#  ('W-305', 57),
#  ('W-414', 58),
#  ('W-315', 58),
#  ('W-681', 58),
#  ('W-187', 58),
#  ('W-581', 58),
#  ('W-196', 58),
#  ('W-125', 59),
#  ('W-504', 59),
#  ('W-977', 59),
#  ('W-535', 59),
#  ('W-616', 59),
#  ('W-984', 59),
#  ('W-717', 59),
#  ('W-885', 59),
#  ('W-130', 60),
#  ('W-912', 60),
#  ('W-304', 60),
#  ('W-733', 60),
#  ('W-544', 60),
#  ('W-499', 60),
#  ('W-745', 60),
#  ('W-394', 60),
#  ('W-516', 61),
#  ('W-986', 61),
#  ('W-270', 61),
#  ('W-850', 61),
#  ('W-1075', 61),
#  ('W-218', 61),
#  ('W-389', 62),
#  ('W-317', 62),
#  ('W-438', 62),
#  ('W-33', 62),
#  ('W-571', 62),
#  ('W-1104', 62),
#  ('W-747', 62),
#  ('W-241', 62),
#  ('W-340', 63),
#  ('W-470', 63),
#  ('W-1016', 63),
#  ('W-1054', 63),
#  ('W-553', 63),
#  ('W-144', 63),
#  ('W-621', 63),
#  ('W-341', 63),
#  ('W-1047', 63),
#  ('W-330', 64),
#  ('W-1121', 64),
#  ('W-561', 64),
#  ('W-133', 64),
#  ('W-169', 64),
#  ('W-573', 64),
#  ('W-614', 64),
#  ('W-997', 65),
#  ('W-301', 65),
#  ('W-476', 65),
#  ('W-703', 65),
#  ('W-411', 65),
#  ('W-60', 65),
#  ('W-1093', 65),
#  ('W-689', 65),
#  ('W-606', 65),
#  ('W-1117', 65),
#  ('W-128', 65),
#  ('W-6', 66),
#  ('W-307', 66),
#  ('W-705', 66),
#  ('W-1044', 66),
#  ('W-967', 66),
#  ('W-357', 66),
#  ('W-1150', 66),
#  ('W-1031', 66),
#  ('W-277', 66),
#  ('W-285', 67),
#  ('W-957', 67),
#  ('W-1073', 67),
#  ('W-485', 67),
#  ('W-160', 67),
#  ('W-971', 67),
#  ('W-666', 67),
#  ('W-40', 67),
#  ('W-98', 67),
#  ('W-869', 68),
#  ('W-388', 68),
#  ('W-42', 68),
#  ('W-29', 68),
#  ('W-387', 68),
#  ('W-92', 68),
#  ('W-440', 69),
#  ('W-523', 69),
#  ('W-1071', 70),
#  ('W-564', 70),
#  ('W-1125', 70),
#  ('W-1098', 70),
#  ('W-585', 70),
#  ('W-120', 70),
#  ('W-215', 70),
#  ('W-579', 70),
#  ('W-687', 71),
#  ('W-1', 71),
#  ('W-962', 71),
#  ('W-751', 71),
#  ('W-64', 71),
#  ('W-1097', 71),
#  ('W-273', 72),
#  ('W-905', 72),
#  ('W-816', 72),
#  ('W-629', 72),
#  ('W-1127', 72),
#  ('W-49', 72),
#  ('W-284', 72),
#  ('W-927', 72),
#  ('W-880', 72),
#  ('W-50', 73),
#  ('W-123', 73),
#  ('W-922', 73),
#  ('W-2', 73),
#  ('W-1107', 73),
#  ('W-862', 74),
#  ('W-874', 74),
#  ('W-887', 74),
#  ('W-479', 74),
#  ('W-127', 74),
#  ('W-663', 74),
#  ('W-186', 74),
#  ('W-890', 74),
#  ('W-529', 74),
#  ('W-891', 74),
#  ('W-1069', 74),
#  ('W-1009', 74),
#  ('W-808', 75),
#  ('W-546', 75),
#  ('W-101', 75),
#  ('W-1120', 75),
#  ('W-1140', 75),
#  ('W-852', 75),
#  ('W-550', 75),
#  ('W-379', 76),
#  ('W-247', 76),
#  ('W-142', 76),
#  ('W-826', 76),
#  ('W-934', 76),
#  ('W-467', 76),
#  ('W-382', 76),
#  ('W-107', 76),
#  ('W-670', 77),
#  ('W-671', 77),
#  ('W-526', 77),
#  ('W-950', 77),
#  ('W-812', 77),
#  ('W-1099', 77),
#  ('W-342', 78),
#  ('W-408', 78),
#  ('W-272', 78),
#  ('W-343', 78),
#  ('W-1025', 79),
#  ('W-955', 79),
#  ('W-558', 79),
#  ('W-672', 79),
#  ('W-1116', 79),
#  ('W-759', 79),
#  ('W-519', 79),
#  ('W-44', 79),
#  ('W-888', 80),
#  ('W-970', 80),
#  ('W-358', 81),
#  ('W-5', 81),
#  ('W-715', 81),
#  ('W-376', 81),
#  ('W-949', 81),
#  ('W-280', 81),
#  ('W-55', 81),
#  ('W-474', 82),
#  ('W-113', 82),
#  ('W-632', 82),
#  ('W-873', 83),
#  ('W-1011', 83),
#  ('W-679', 83),
#  ('W-286', 83),
#  ('W-965', 83),
#  ('W-1156', 83),
#  ('W-665', 83),
#  ('W-625', 83),
#  ('W-1055', 84),
#  ('W-832', 85),
#  ('W-90', 85),
#  ('W-232', 85),
#  ('W-219', 85),
#  ('W-149', 85),
#  ('W-1063', 86),
#  ('W-437', 87),
#  ('W-1103', 88),
#  ('W-345', 88),
#  ('W-652', 88),
#  ('W-449', 88),
#  ('W-604', 88),
#  ('W-320', 88),
#  ('W-39', 88),
#  ('W-1070', 88),
#  ('W-452', 88),
#  ('W-881', 89),
#  ('W-488', 89),
#  ('W-103', 89),
#  ('W-78', 89),
#  ('W-81', 89),
#  ('W-412', 90),
#  ('W-655', 90),
#  ('W-1045', 90),
#  ('W-796', 91),
#  ('W-253', 91),
#  ('W-959', 91),
#  ('W-534', 91),
#  ('W-896', 91),
#  ('W-141', 91),
#  ('W-788', 92),
#  ('W-248', 92),
#  ('W-697', 92),
#  ('W-914', 92),
#  ('W-204', 92),
#  ('W-426', 93),
#  ('W-496', 93),
#  ('W-26', 93),
#  ('W-586', 93),
#  ('W-31', 93),
#  ('W-1145', 94),
#  ('W-844', 94),
#  ('W-985', 95),
#  ('W-335', 95),
#  ('W-95', 96),
#  ('W-366', 96),
#  ('W-638', 97),
#  ('W-1020', 97),
#  ('W-762', 97),
#  ('W-939', 97),
#  ('W-442', 97),
#  ('W-429', 97),
#  ('W-1161', 97),
#  ('W-662', 97),
#  ('W-806', 98),
#  ('W-403', 98),
#  ('W-441', 98),
#  ('W-1007', 99),
#  ('W-202', 99),
#  ('W-439', 100),
#  ('W-952', 101),
#  ('W-804', 101),
#  ('W-958', 101),
#  ('W-549', 102),
#  ('W-10', 102),
#  ('W-823', 102),
#  ('W-735', 102),
#  ('W-158', 102),
#  ('W-951', 102),
#  ('W-250', 103),
#  ('W-319', 104),
#  ('W-261', 104),
#  ('W-784', 104),
#  ('W-693', 105),
#  ('W-1083', 105),
#  ('W-1136', 105),
#  ('W-756', 105),
#  ('W-205', 105),
#  ('W-245', 105),
#  ('W-963', 106),
#  ('W-237', 106),
#  ('W-966', 106),
#  ('W-287', 107),
#  ('W-1157', 108),
#  ('W-52', 108),
#  ('W-87', 108),
#  ('W-883', 108),
#  ('W-595', 109),
#  ('W-979', 109),
#  ('W-344', 109),
#  ('W-288', 110),
#  ('W-164', 110),
#  ('W-539', 110),
#  ('W-58', 111),
#  ('W-908', 111),
#  ('W-936', 111),
#  ('W-752', 111),
#  ('W-1008', 112),
#  ('W-375', 112),
#  ('W-1110', 112),
#  ('W-831', 112),
#  ('W-15', 113),
#  ('W-740', 113),
#  ('W-513', 114),
#  ('W-378', 114),
#  ('W-853', 114),
#  ('W-309', 114),
#  ('W-12', 115),
#  ('W-11', 115),
#  ('W-82', 115),
#  ('W-303', 116),
#  ('W-568', 116),
#  ('W-465', 116),
#  ('W-1019', 117),
#  ('W-1090', 117),
#  ('W-515', 117),
#  ('W-225', 118),
#  ('W-560', 118),
#  ('W-641', 118),
#  ('W-569', 119),
#  ('W-892', 119),
#  ('W-385', 119),
#  ('W-555', 119),
#  ('W-734', 119),
#  ('W-956', 119),
#  ('W-494', 119),
#  ('W-126', 120),
#  ('W-702', 120),
#  ('W-1026', 121),
#  ('W-393', 122),
#  ('W-976', 122),
#  ('W-609', 122),
#  ('W-318', 122),
#  ('W-1134', 122),
#  ('W-748', 123),
#  ('W-410', 124),
#  ('W-1101', 124),
#  ('W-423', 124),
#  ('W-525', 124),
#  ('W-993', 125),
#  ('W-911', 125),
#  ('W-938', 125),
#  ('W-77', 126),
#  ('W-325', 126),
#  ('W-669', 127),
#  ('W-334', 127),
#  ('W-514', 128),
#  ('W-100', 128),
#  ('W-688', 129),
#  ('W-1067', 130),
#  ('W-1043', 130),
#  ('W-415', 130),
#  ('W-1112', 131),
#  ('W-134', 131),
#  ('W-566', 131),
#  ('W-793', 132),
#  ('W-329', 132),
#  ('W-648', 132),
#  ('W-59', 132),
#  ('W-27', 132),
#  ('W-1024', 133),
#  ('W-221', 133),
#  ('W-659', 133),
#  ('W-477', 133),
#  ('W-1072', 134),
#  ('W-138', 134),
#  ('W-994', 134),
#  ('W-835', 134),
#  ('W-1135', 135),
#  ('W-427', 135),
#  ('W-19', 135),
#  ('W-906', 135),
#  ('W-46', 135),
#  ('W-716', 136),
#  ('W-565', 136),
#  ('W-631', 136),
#  ('W-336', 136),
#  ('W-72', 136),
#  ('W-982', 137),
#  ('W-300', 137),
#  ('W-791', 137),
#  ('W-1092', 137),
#  ('W-3', 138),
#  ('W-71', 138),
#  ('W-23', 138),
#  ('W-466', 139),
#  ('W-493', 139),
#  ('W-405', 139),
#  ('W-298', 139),
#  ('W-179', 140),
#  ('W-30', 140),
#  ('W-222', 140),
#  ('W-1064', 140),
#  ('W-61', 140),
#  ('W-1039', 140),
#  ('W-401', 141),
#  ('W-1060', 141),
#  ('W-821', 141),
#  ('W-551', 141),
#  ('W-929', 141),
#  ('W-822', 143),
#  ('W-1034', 143),
#  ('W-948', 143),
#  ('W-650', 143),
#  ('W-592', 143),
#  ('W-645', 144),
#  ('W-1036', 144),
#  ('W-1089', 145),
#  ('W-269', 146),
#  ('W-618', 146),
#  ('W-588', 146),
#  ('W-1082', 147),
#  ('W-877', 147),
#  ('W-766', 147),
#  ('W-99', 148),
#  ('W-406', 148),
#  ('W-736', 148),
#  ('W-893', 148),
#  ('W-413', 150),
#  ('W-521', 150),
#  ('W-7', 150),
#  ('W-1163', 150),
#  ('W-381', 151),
#  ('W-116', 151),
#  ('W-333', 152),
#  ('W-765', 152),
#  ('W-777', 152),
#  ('W-502', 152),
#  ('W-0', 153),
#  ('W-207', 153),
#  ('W-545', 153),
#  ('W-886', 154),
#  ('W-165', 156),
#  ('W-208', 156),
#  ('W-657', 156),
#  ('W-512', 157),
#  ('W-166', 157),
#  ('W-680', 157),
#  ('W-607', 160),
#  ('W-206', 160),
#  ('W-497', 160),
#  ('W-323', 160),
#  ('W-824', 161),
#  ('W-446', 161),
#  ('W-362', 161),
#  ('W-181', 162),
#  ('W-313', 163),
#  ('W-946', 164),
#  ('W-633', 164),
#  ('W-774', 165),
#  ('W-636', 165),
#  ('W-991', 165),
#  ('W-1106', 166),
#  ('W-462', 167),
#  ('W-557', 167),
#  ('W-617', 167),
#  ('W-114', 169),
#  ('W-981', 169),
#  ('W-615', 170),
#  ('W-658', 170),
#  ('W-634', 171),
#  ('W-772', 174),
#  ('W-620', 174),
#  ('W-664', 174),
#  ('W-136', 175),
#  ('W-918', 177),
#  ('W-677', 177),
#  ('W-1147', 177),
#  ('W-274', 179),
#  ('W-255', 180),
#  ('W-1068', 180),
#  ('W-834', 180),
#  ('W-481', 181),
#  ('W-1061', 181),
#  ('W-110', 183),
#  ('W-157', 183),
#  ('W-961', 184),
#  ('W-152', 185),
#  ('W-295', 187),
#  ('W-695', 187),
#  ('W-656', 188),
#  ('W-170', 188),
#  ('W-920', 189),
#  ('W-433', 189),
#  ('W-428', 190),
#  ('W-1062', 190),
#  ('W-337', 190),
#  ('W-180', 191),
#  ('W-490', 191),
#  ('W-115', 191),
#  ('W-743', 192),
#  ('W-447', 193),
#  ('W-972', 194),
#  ('W-65', 194),
#  ('W-578', 194),
#  ('W-436', 195),
#  ('W-1017', 196),
#  ('W-131', 196),
#  ('W-262', 196),
#  ('W-1057', 197),
#  ('W-790', 197),
#  ('W-1078', 198),
#  ('W-145', 201),
#  ('W-960', 201),
#  ('W-651', 202),
#  ('W-583', 203),
#  ('W-1100', 203),
#  ('W-998', 205),
#  ('W-124', 207),
#  ('W-484', 207),
#  ('W-182', 207),
#  ('W-543', 208),
#  ('W-178', 209),
#  ('W-989', 210),
#  ('W-88', 211),
#  ('W-291', 211),
#  ('W-807', 211),
#  ('W-183', 211),
#  ('W-542', 211),
#  ('W-1001', 212),
#  ('W-611', 212),
#  ('W-328', 213),
#  ('W-35', 213),
#  ('W-524', 214),
#  ('W-353', 215),
#  ('W-146', 216),
#  ('W-435', 217),
#  ('W-1032', 217),
#  ('W-1000', 218),
#  ('W-723', 218),
#  ('W-76', 218),
#  ('W-263', 219),
#  ('W-760', 220),
#  ('W-678', 222),
#  ('W-302', 223),
#  ('W-507', 223),
#  ('W-79', 223),
#  ('W-80', 224),
#  ('W-177', 226),
#  ('W-548', 226),
#  ('W-349', 227),
#  ('W-48', 228),
#  ('W-701', 228),
#  ('W-324', 230),
#  ('W-1084', 230),
#  ('W-770', 234),
#  ('W-987', 234),
#  ('W-628', 236),
#  ('W-1123', 237),
#  ('W-768', 237),
#  ('W-500', 238),
#  ('W-89', 239),
#  ('W-691', 239),
#  ('W-775', 242),
#  ('W-653', 242),
#  ('W-1146', 243),
#  ('W-894', 245),
#  ('W-518', 246),
#  ('W-1029', 247),
#  ('W-1115', 248),
#  ('W-351', 249),
#  ('W-980', 250),
#  ('W-1132', 251),
#  ('W-230', 253),
#  ('W-252', 255),
#  ('W-995', 259),
#  ('W-738', 261),
#  ('W-434', 261),
#  ('W-176', 261),
#  ('W-188', 262),
#  ('W-367', 262),
#  ('W-945', 263),
#  ('W-923', 264),
#  ('W-195', 266),
#  ('W-475', 267),
#  ('W-829', 267),
#  ('W-400', 268),
#  ('W-810', 269),
#  ('W-1038', 269),
#  ('W-267', 269),
#  ('W-167', 269),
#  ('W-41', 270),
#  ('W-867', 276),
#  ('W-258', 278),
#  ('W-391', 279),
#  ('W-562', 280),
#  ('W-767', 282),
#  ('W-597', 283),
#  ('W-1004', 284),
#  ('W-899', 284),
#  ('W-501', 287),
#  ('W-714', 287),
#  ('W-1046', 288),
#  ('W-492', 289),
#  ('W-602', 292),
#  ('W-217', 292),
#  ('W-243', 295),
#  ('W-293', 296),
#  ('W-814', 297),
#  ('W-619', 298),
#  ('W-339', 298),
#  ('W-395', 300),
#  ('W-471', 301),
#  ('W-251', 303),
#  ('W-593', 303),
#  ('W-649', 304),
#  ('W-282', 305),
#  ('W-608', 306),
#  ('W-570', 308),
#  ('W-612', 309),
#  ('W-1003', 312),
#  ('W-463', 312),
#  ('W-338', 313),
#  ('W-224', 313),
#  ('W-372', 314),
#  ('W-996', 318),
#  ('W-356', 321),
#  ('W-926', 323),
#  ('W-527', 325),
#  ('W-398', 326),
#  ('W-725', 326),
#  ('W-709', 328),
#  ('W-193', 328),
#  ('W-895', 330),
#  ('W-135', 331),
#  ('W-613', 332),
#  ('W-1128', 341),
#  ('W-953', 341),
#  ('W-919', 345),
#  ('W-1059', 345),
#  ('W-700', 347),
#  ('W-528', 348),
#  ('W-932', 348),
#  ('W-854', 348),
#  ('W-17', 350),
#  ('W-968', 354),
#  ('W-933', 356),
#  ('W-675', 357),
#  ('W-699', 358),
#  ('W-491', 363),
#  ('W-147', 363),
#  ('W-1074', 365),
#  ('W-778', 366),
#  ('W-346', 366),
#  ('W-28', 367),
#  ('W-424', 369),
#  ('W-750', 369),
#  ('W-129', 370),
#  ('W-626', 370),
#  ('W-430', 371),
#  ('W-916', 372),
#  ('W-443', 375),
#  ('W-779', 377),
#  ('W-91', 377),
#  ('W-1006', 382),
#  ('W-749', 382),
#  ('W-590', 383),
#  ('W-392', 387),
#  ('W-1139', 387),
#  ('W-683', 391),
#  ('W-856', 391),
#  ('W-68', 399),
#  ('W-18', 400),
#  ('W-364', 400),
#  ('W-432', 401),
#  ('W-148', 401),
#  ('W-536', 406),
#  ('W-370', 407),
#  ('W-742', 410),
#  ('W-815', 411),
#  ('W-1058', 414),
#  ('W-731', 415),
#  ('W-402', 422),
#  ('W-1018', 426),
#  ('W-289', 428),
#  ('W-992', 434),
#  ('W-327', 434),
#  ('W-833', 436),
#  ('W-1065', 437),
#  ('W-211', 439),
#  ('W-161', 458),
#  ('W-326', 459),
#  ('W-194', 461),
#  ('W-531', 461),
#  ('W-132', 461),
#  ('W-16', 464),
#  ('W-858', 464),
#  ('W-1141', 465),
#  ('W-847', 473),
#  ('W-118', 475),
#  ('W-1151', 479),
#  ('W-1094', 485),
#  ('W-1113', 485),
#  ('W-627', 487),
#  ('W-754', 487),
#  ('W-783', 492),
#  ('W-708', 492),
#  ('W-787', 498),
#  ('W-732', 503),
#  ('W-365', 504),
#  ('W-563', 508),
#  ('W-453', 509),
#  ('W-682', 509),
#  ('W-223', 510),
#  ('W-761', 513),
#  ('W-43', 513),
#  ('W-448', 515),
#  ('W-297', 517),
#  ('W-1051', 519),
#  ('W-879', 521),
#  ('W-931', 523),
#  ('W-469', 526),
#  ('W-171', 533),
#  ...]

# %% [markdown]
# ## 5. Резделение на обучение и тест

# %%
lenta_train, lenta_test = train_test_split(lenta, test_size=0.2, shuffle=True, random_state=SEED)

# %% [markdown]
# ## 6. Сохранение данных

# %%
lenta_train.to_csv("../data/lenta_train.csv", index=False, header=True)
lenta_test.to_csv("../data/lenta_test.csv", index=False, header=True)
